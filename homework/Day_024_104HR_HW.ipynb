# %% [markdown]
# # 104人力銀行網站爬蟲練習
# ## 從104人力銀行網站爬取求職公司資訊。

# %%
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### 首先進入104人力銀行網站：https://www.104.com.tw/cust/list/index/
# ### 在"地區"及"產業"下拉式選單中，選擇你希望的選項，然後按下"找公司"按鈕。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 開啟新網頁後，觀察新的網址內容，把網址複製下來。

# %%
job_104_url = "https://www.104.com.tw/cust/list/index/?page=1&order=1&mode=s&jobsource=checkc&area=6001001000&indcat=1001002000"

# %% [markdown]
# ### 開始爬取搜尋結果

# %%
browser = webdriver.Chrome("/Users/Pacy/Downloads/chromedriver-2")
browser.get(job_104_url)  # 打開瀏覽器並連到網頁
time.sleep(2)  # delay一段時間等待網頁更新完成

pages = 0 

while pages<=8:
    time.sleep(3)  # delay一段時間等待網頁更新完成
    html = browser.page_source
    soup = BeautifulSoup(html, 'lxml')
    company_list = soup.find("div", attrs={'id':"company-result"}).find_all("article", attrs={'class':"items"})
    
    #
    # 擷取公司名稱及簡介內容
    #
    for company in company_list:
        # 因為內容太多，我們把爬取到的結果，寫入"company_list.txt"檔案中，稍後再來檢視
        company_name = company.a.string
        f = open("company_list.txt", "a+", encoding='utf-8')
        f.write( company_name + "\n" )  # 寫入公司名稱
        
        company_desc = company.find("p", attrs={'class':"desc"})
        f.write( company_desc.string + "\n" )  # 寫入公司簡介
        f.write( "--------------------------------------------------------------------------------" + "\n" )
        f.close()
    
    element = browser.find_element_by_link_text("下一頁")
    element.click()
    pages += 1 

    
print("==========沒有下一頁了==========")
browser.quit()

'''
    
    接下來請學員練習，定位到「下一頁」按鈕。(可以利用find_element_by_link_text("xxx")的函式)
    如果還有下一頁，利用Selenium模擬click「下一頁」按鈕的動作。(定位到物件後，利用其click()屬性)
    若沒有下一頁了，離開爬取的流程
    
    Your code here'''
# Out:
# ==========沒有下一頁了==========
# '\n    \n    接下來請學員練習，定位到「下一頁」按鈕。(可以利用find_element_by_link_text("xxx")的函式)\n    如果還有下一頁，利用Selenium模擬click「下一頁」按鈕的動作。(定位到物件後，利用其click()屬性)\n    若沒有下一頁了，離開爬取的流程\n    \n    Your code here'

# %%
#練習
import time 
from bs4 import BeautifulSoup 
from selenium import webdriver 
from selenium.webdriver.common.keys import Keys 

job_104_url ="https://www.104.com.tw/cust/list/index/?page=1&order=1&mode=s&jobsource=checkc&area=6001001000&indcat=1001002000"

browser = webdriver.Chrome("/Users/Pacy/Downloads/chromedriver-2")
browser.get(job_104_url)
html = browser.page_source 
soup = BeautifulSoup(html,"lxml")
print(soup)
# Out:
# <html lang="zh-tw"><!--<![endif]--><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="no-cache" http-equiv="cache-control"/>
# <link href="https://static.104.com.tw/104main/jb/css/common.css?v=20170330" rel="stylesheet" type="text/css"/>
# <link href="https://static.104.com.tw/bubble/css/alert.css?v=20170330" rel="stylesheet" type="text/css"/>
# <link href="https://static.104.com.tw/104main/pda/css/category_org.css?v=20170330" rel="stylesheet" type="text/css"/>
# <link href="https://www.104.com.tw/css/AutoSuggest.css?v=20170330" rel="stylesheet" type="text/css"/>
# <link href="https://static.104.com.tw/104main/jb/css/search.css?v=20170330" rel="stylesheet" type="text/css"/>
# <script async="" id="logjsapi" src="//static.104.com.tw/104i/js/api/log/e104.log.latest.js?v=20201028" type="text/javascript"></script><script async="" src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/gtm/js?id=GTM-PQLT46R&amp;t=gtm2&amp;cid=1470400561.1609601576" type="text/javascript"></script><script async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-FJWMQR9J2K&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-W9X1GB1SVR&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-P379T3"></script><script async="" id="logjsapi" src="https://static.104.com.tw/104i/js/api/log/e104.log.latest.js?v=20150611 " type="text/javascript"></script><script async="" src="https://d31qbv1cthcecs.cloudfront.net/atrk.js" type="text/javascript"></script><script src="https://static.104.com.tw/104main/js/jquery/jquery.min.js?v=20170330" type="text/javascript"></script>
# <script src="https://static.104.com.tw/104main/jb/js/jbajax.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/bubble/js/mainjs.js?by=jbbar&amp;v=20170330" type="text/javascript"></script><link href="//static.104.com.tw/bubble/css/alert.css?v=20140701" rel="stylesheet" type="text/css"/><script src="//www.104.com.tw/jobbank/globalbar/globaljson_website.js?v=20140701"></script><script language="javascript" src="//bubble.104.com.tw/js/showbarright" type="text/javascript"></script><script src="//www.104.com.tw/jobbank/globalbar/globaljson_more.js?v=20140701"></script><script src="//www.104.com.tw/jobbank/globalbar/globaljson_notice.js?v=20140701"></script><script src="//static.104.com.tw/104main/js/jquery/jquery.bgiframe.js?v=20140701"></script><script src="//static.104.com.tw/bubble/js/jquery.104bar.js?v=20140701"></script>
# <script charset="UTF-8" type="text/javascript">
# /*<![CDATA[*/
# var mateLetter=''; var toPlus='false';
# var enPid='';
# var companyConds={"page":"1","area":{"no":"6001001000","desc":"\u53f0\u5317\u5e02"},"indcat":{"no":"1001002000","desc":"\u96fb\u4fe1\u53ca\u901a\u8a0a\u76f8\u95dc\u696d"},"order":{"no":"1"},"mode":"s","jobsource":"checkc"};
# var g_baseUrl='/cust';
# var g_staticUrl='https://static.104.com.tw/104main';
# var g_mainUrl='https://www.104.com.tw';
# var g_pdaUrl='https://pda.104.com.tw';
# var g_accountsUrl='https://accounts.104.com.tw';
# /*]]>*/
# </script>
# <title>台北市、電信及通訊相關業等相關公司 - 104 人力銀行</title>
# <meta content="104人力銀行中符合台北市、電信及通訊相關業等條件的相關公司" name="description"/>
# <meta content="台北市、電信及通訊相關業" name="keyword"/>
# <!--[if lt IE 9]>
# <script src="https://static.104.com.tw/104main/js/html5shiv.js"></script>
# <script src="https://static.104.com.tw/104main/jb/js/lib/es5-shim.min.js"></script>
# <script src="https://static.104.com.tw/104main/jb/js/lib/es5-sham.min.js"></script>
# <![endif]-->
# <script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/968874231/?random=1609601576082&amp;cv=9&amp;fst=1609601576082&amp;num=1&amp;bg=ffffff&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=900&amp;u_w=1440&amp;u_ah=854&amp;u_aw=1440&amp;u_cd=24&amp;u_his=2&amp;u_tz=480&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2oabu0&amp;sendb=1&amp;ig=1&amp;data=event%3Dgtag.config&amp;frm=0&amp;url=https%3A%2F%2Fwww.104.com.tw%2Fcust%2Flist%2Findex%2F%3Fpage%3D1%26order%3D1%26mode%3Ds%26jobsource%3Dcheckc%26area%3D6001001000%26indcat%3D1001002000&amp;tiba=%E5%8F%B0%E5%8C%97%E5%B8%82%E3%80%81%E9%9B%BB%E4%BF%A1%E5%8F%8A%E9%80%9A%E8%A8%8A%E7%9B%B8%E9%97%9C%E6%A5%AD%E7%AD%89%E7%9B%B8%E9%97%9C%E5%85%AC%E5%8F%B8%20-%20104%20%E4%BA%BA%E5%8A%9B%E9%8A%80%E8%A1%8C&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script></head>
# <body><div style="position: absolute;"><object classid="clsid:D27CDB6E-AE6D-11cf-96B8-444553540000" codebase="http://download.macromedia.com/pub/shockwave/cabs/flash/swflash.cab" height="0" id="SharedObjectAPI_ID" width="0"><param name="movie" value="https://www.104.com.tw/public/104main/swf/SharedObjectAPI.swf?t=1609601574047"/><param name="quality" value="high"/><param name="bgcolor" value="#000"/><param name="allowScriptAccess" value="sameDomain"/><embed align="middle" allowscriptaccess="sameDomain" bgcolor="#000" height="0" loop="false" name="SharedObjectAPI_ID" play="true" pluginspage="http://www.macromedia.com/go/getflashplayer" quality="high" src="https://www.104.com.tw/public/104main/swf/SharedObjectAPI.swf?t=1609601574047" type="application/x-shockwave-flash" width="0"/></object></div>
# <div id="globalbar"><div id="bar_m104"><div id="global_bk"><ul class="global_lr"><li class="left"><ul class="global_nav" id="web_link"><li class="on"><a href="https://www.104.com.tw/" onclick="gcn('_index');" target="">104人力銀行</a></li><li class="c_title"><a href="https://pda.104.com.tw/" onclick="gcn('_my104');" rel="nofollow" target="">My104</a></li><li><a href="https://top.104.com.tw/?utm_source=104PC&amp;utm_medium=BB&amp;utm_campaign=104top" onclick="gcn('_tutor');" target="_blank">家教/外包</a></li><li><a href="https://blog.104.com.tw/category/job-search/resume-interview/?utm_source=104&amp;utm_medium=blackbar_B" onclick="gcn('_case');" target="_blank">職場力</a></li><li><a href="https://hunter.104.com.tw/TC/index.jsp?trc=104b&amp;utm_source=JB&amp;utm_medium=bar" onclick="gcn('_giver');" target="_blank">獵才</a></li><li><a href="http://www.104.com.tw/cfdocs/project/adpda08/ad20191216_23818.htm" onclick="gcn('_bravo');" target="_blank">掌聲</a></li><li class="personal"><a href="#" onclick="gcn('_family');return false;">更多<span></span></a><ul class="global_sub" style="left:-1px; width:712px;"><li><div class="navi_box box"><div class="web_box"><ul><li><a href="https://senior.104.com.tw?utm_source=official_104&amp;utm_medium=104_GlobalBar" onclick="gcn('_family33');" target="_blank">高年級</a></li><li><a href="https://reviews.104.com.tw/?utm_source=104main&amp;utm_medium=global_bar&amp;utm_campaign=reviews" onclick="gcn('_family34');" target="_blank">公司評論</a></li><li><a href="https://careu.104.com.tw" onclick="gcn('_family31');" target="_blank">銀髮銀行</a></li><li><a href="https://www.104.com.tw/area/startup/" onclick="gcn('_family29');" target="_blank">新創企業</a></li><li><a href="https://www.104.com.tw/jb/104i/wage/view?wf=alertbar" onclick="gcn('_family18');" target="_blank">薪資情報</a></li><li class="group_line"><div></div></li><li><a href="http://www.104.com.tw/cfdocs/project/adpda08/ad20190807_23487.htm" onclick="gcn('_family22');" target="_blank">104觀點</a></li><li><a href="https://www.104.com.tw/area/seminar/" onclick="gcn('_family28');" target="_blank">104講堂</a></li><li><a href="https://www.104.com.tw/mobile/index.htm" onclick="gcn('_family26');" target="_blank">手機服務</a></li><li class="group_line"><div></div></li><li><a href="https://www.104.com.tw/jobs/main/sitemap" onclick="gcn('_family104');" target="_blank">全部 》</a></li></ul></div></div></li></ul></li><li><a href="https://blog.104.com.tw/what-is-your-weakness-best-answer/?utm_source=104&amp;utm_medium=1228blackbar" onclick="gcn('_ad');" target="_blank" title=""><font color="#FFFF20">面試被問缺點要用優點包裝？錯了</font></a></li></ul></li><li class="right"><ul class="global_nav"> <li><a class="browser" href="#" onclick="gcn('_read');return false;" title="看過我的公司"></a> <ul class="global_sub"> <li> <div class="box alertbar_browser"> <h3>看過我的公司</h3> <p> </p> <p><a class="more" href="#" onclick="sendToMy104(19,0,1);return false;">請先登入會員</a></p> </div> </li> </ul> </li> <li><a class="letter" href="#" onclick="gcn('_letter');return false;" title="通知我的公司"></a> <ul class="global_sub"> <li> <div class="box alertbar_letter"> <h3>通知我的公司</h3> <p> </p> <p><a class="more" href="#" onclick="sendToMy104(20,0,1);return false;">請先登入會員</a></p> </div> </li> </ul> </li> <li><a class="newjob" href="#" onclick="gcn('_newjob');return false;" title="配對工作"></a> <ul class="global_sub"> <li> <div class="box alertbar_newjob"> <h3>配對工作</h3> <p> </p> <p><a class="more" href="#" onclick="sendToMy104(14,0,1);return false;">請先登入會員</a></p> </div> </li> </ul> </li><li class="personal"><a href="#" id="name_link" onclick="gcn('_id');return false;">帳號<span></span></a> <ul class="global_sub"> <li> <div class="personal_box box"> <dl> <dt><a href="//login.104.com.tw/register?source_partner=alertbar" onclick="gcn('_newnumber');" rel="nofollow" target="_blank">My104會員註冊</a></dt> <dt><a href="//www.104.com.tw/jobbank/faq/index.cfm" onclick="gcn('_ask');" rel="nofollow" target="_blank">常見問題</a></dt> <dt><a href="//www.104.com.tw/question_admin/rea ...
# <header id="hd-min">
# <h1>
# <a href="https://www.104.com.tw" title="104人力銀行">
# <img alt="104 人力銀行" src="https://static.104.com.tw/logo/104logo_o_119x24.png"/>
# </a>
# </h1>
# <div class="ad-box banner">
# <div id="aidma_130"><a href="javascript:e104aidma_click('aidma_130,2,8,130,1,54962,https://bit.ly/38zVraJ?jobsource=130_1_54962_,true,0');"><img border="0" height="60" src="https://static.104.com.tw/aidma/material/8/130/1_54962.jpg" width="728"/></a><img id="aidma_viewclick_54962" src="https://static.104.com.tw/aidma/view_click.gif?param=view_2_8_130_1_54962&amp;rnd=1609601574439" style="display:none;"/></div>
# </div>
# <div class="ad-box text">強力放送
# 		<div id="aidma_134"><a href="javascript:e104aidma_click('aidma_134,2,8,134,2,45880,https://top.104.com.tw/caseList?utm_source=104PC&amp;utm_medium=PR&amp;utm_campaign=case-list&amp;jobsource=134_2_45880_,true,0');">接案兼差賺外快，入門免經驗立即應徵，看看最新案件＞＞</a><img id="aidma_viewclick_45880" src="https://static.104.com.tw/aidma/view_click.gif?param=view_2_8_134_2_45880&amp;rnd=1609601574440" style="display:none;"/></div>
# </div>
# </header>
# <div id="hd-search">
# <div class="mid">
# <div class="fillin">
# <form action="/cust/list/index" id="hd-conds" method="post">
# <input autocomplete="off" class="fill-text fill-keyword" id="fill-keyword" name="keyword" placeholder="公司名、產品名或品牌名" type="text" value=""/>
# <div class="fake-select fill-city" data-placeholder="地區" id="fill-city">
# <span class="opts">台北市</span>
# <span class="jbi-s15-angle-down"></span>
# </div>
# <div class="fake-select fill-industry" data-placeholder="產業" id="fill-industry">
# <span class="opts">電信及通訊相關業</span>
# <span class="jbi-s15-angle-down"></span>
# </div>
# <input id="area" name="area" type="hidden" value="6001001000"/>
# <input id="indcat" name="indcat" type="hidden" value="1001002000"/>
# <input id="emp" name="emp" type="hidden" value=""/><!-- 員工人數 -->
# <input id="cpt" name="cpt" type="hidden" value=""/><!-- 資本額 -->
# <input id="order" name="order" type="hidden" value="1"/><!-- 目前排序 -->
# <input id="mode" name="mode" type="hidden" value="s"/><!-- 切換模式:網址有參數就要帶進去  -->
# <input id="page" name="page" type="hidden" value="1"/><!-- 頁數一定重1開始... -->
# <button class="button primary act-search" type="submit">找公司</button>
# </form>
# <div class="clearfix"></div>
# </div>
# <div class="conditions">
# 			查詢條件：<span class="labels"><a class="items" data-type="area" data-value="6001001000">台北市<i class="jbi-s15-delete-red"></i></a><a class="items" data-type="indcat" data-value="1001002000">電信及通訊相關業<i class="jbi-s15-delete-red"></i></a></span>
# </div>
# </div>
# </div>
# <div class="wrap main-right" id="search-result">
# <main class="main">
# <!-- 排序&mode切換BLOCK start -->
# <div class="order">
# 				目前的排序：
# 		<select class="styled-select" id="select-order" name="select-order">
# <option selected="" value="1">相關性</option>
# <option value="4">資本額</option>
# <option value="5">員工人數</option>
# </select>
# </div>
# <div class="display">
# <span class="mode">
# <a class="active" data-mode="s" href="/cust/list/index?mode=s&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;jobsource=checkc">摘要</a>|
# 	        <a data-mode="l" href="/cust/list/index?mode=l&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;jobsource=checkc">列表</a>
# </span>
# <span class="total">共 <span>234</span> 筆</span>
# </div>
# <!-- 排序&mode切換BLOCK end -->
# <div class="clearfix"></div>
# <div class="content">
# <div class="loading-mask" style="display: none;">
# <div class="loading-msg">
# <img alt="" src="https://static.104.com.tw/104main/jb/img/loading/64x64.gif"/>
# <span>資料處理中...</span>
# </div>
# </div>
# <div id="company-result"><!-- 摘要模式 -->
# <div class="company-summary">
# <div class="head">
# <span>公司名稱</span>
# </div>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/ao38luo?jobsource=checkc" target="_blank" title="&lt;安立知股份有限公司&gt;">安立知股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：暫不提供</span>
# </p>
# <p class="desc">Anritsu(安立知)集團創建於 1895 年，為全球最主要的量測儀器製造商之一。集團總部設於日本厚木市，研發單位及製造工廠位於日本、美國、英國及丹麥等。Anritsu(安立知)產品包括無線通訊測試、微波射頻元件測試、數據通信測試、光...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/ao38luo?jobsource=checkc#info06" target="_blank">工作機會 (3)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/2000/23224452000/logo.gif?v=20200730174137"/>
# <button class="button act-save" data-custno="ao38luo" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="ao38luo" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <div class="jbi-s18-cust"></div>
# <h1>
# <a href="https://www.104.com.tw/company/wet5lbs?jobsource=checkc" target="_blank" title="&lt;台灣小米通訊有限公司&gt;">台灣小米通訊有限公司</a>
# </h1>
# <p class="data">
# <span>台北市中正區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：500萬元</span>，<span>員工人數：100人</span>
# </p>
# <p class="desc">［小米不是單純的硬體公司，我們是創新驅動的互聯網公司］
# 小米集團成立於2010年4月，2018年7月9日在香港交易所主板掛牌上市（1810.HK），是一家以手機、智慧裝置和 IoT 平台為核心的互聯網公司。
#
# 胸懷「和用戶交朋友，做用戶心...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/wet5lbs?jobsource=checkc#info06" target="_blank">工作機會 (3)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/1000/70552531000/logo.png?v=20200701125426"/>
# <button class="button act-save" data-custno="wet5lbs" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="wet5lbs" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bkb4r?jobsource=checkc" target="_blank" title="&lt;泓博無線通訊技術有限公司&gt;">泓博無線通訊技術有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：暫不提供</span>
# </p>
# <p class="desc">泓淋科技集團是專為3C及汽車领域客户提供無線有線訊號連接產品和特種電纜及組件產品的集團公司
# 集團一直致力於研發實力的提升，能為客户提供一流的設計方案，先后成立高頻訊號傳輸技術研究中心，高分子材料研究中心，天線研發中...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bkb4r?jobsource=checkc#info06" target="_blank">工作機會 (16)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/8635/130000000108635/logo.gif?v=20200730184820"/>
# <button class="button act-save" data-custno="1a2x6bkb4r" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bkb4r" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bim6y?jobsource=checkc" target="_blank" title="&lt;雙偉通聯股份有限公司&gt;">雙偉通聯股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市信義區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：6300萬元</span>，<span>員工人數：50人</span>
# </p>
# <p class="desc">1. 成立日期：2005年
# 2. 總公司： 美國加州矽谷Fremont市
# 3. 研發中心：
#     • 核心技術及伺服器研發中心： Fremont
#     • 全球應用發展中心：台北
#     • 中國技術支援中心：武漢市
# 4. 亞太營運中心：台北
# </p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bim6y?jobsource=checkc#info06" target="_blank">工作機會 (2)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/9658/130000000029658/logo.gif?v=20200730174339"/>
# <button class="button act-save" data-custno="1a2x6bim6y" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bim6y" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/18rsdef4?jobsource=checkc" target="_blank" title="&lt;祐浩實業有限公司&gt;">祐浩實業有限公司</a>
# </h1>
# <p class="data">
# <span>台北市大安區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：500萬元</span>，<span>員工人數：20人</span>
# </p>
# <p class="desc">公司創立至今已29年，經過電信市場民營開放，以及科技不斷創新的衝擊，公司仍能持續發展的理由是，我們堅持初衷，以提供優質商品及完整的服務流程，為我們企業的中心價值。每位同仁盡的心力是公司成長的動能，我們提供優於同業的...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/18rsdef4?jobsource=checkc#info06" target="_blank">工作機會 (5)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/4000/97458664000/logo.jpg?v=20201229170712"/>
# <button class="button act-save" data-custno="18rsdef4" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="18rsdef4" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6biqai?jobsource=checkc" target="_blank" title="&lt;皇家電訊科技有限公司&gt;">皇家電訊科技有限公司</a>
# </h1>
# <p class="data">
# <span>台北市中山區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：100人</span>
# </p>
# <p class="desc">本公司於民國81年開業至今，規模由員工2~3人發展至今有100人以上的規模。
# 由當初一般門市擴業到手機與門號的北市批發通路盤商，隨著通訊的蓬勃發展及產業大幅成長效應下，本公司秉持著「服務好、速度快」的批發配送服務，發展北市...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6biqai?jobsource=checkc#info06" target="_blank">工作機會 (5)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/4970/130000000034970/logo.png?v=20200730174342"/>
# <button class="button act-save" data-custno="1a2x6biqai" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6biqai" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/10u7bork?jobsource=checkc" target="_blank" title="&lt;台灣克羅瓦雷克斯股份有限公司&gt;">台灣克羅瓦雷克斯股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市中山區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：100萬元</span>，<span>員工人數：185人</span>
# </p>
# <p class="desc">總公司設立於東京,並於沖繩及台灣各設有分公司，
# 東京主要業務:管理,業務,技術開發,程式設計等。
# 沖繩分公司:技術開發,程式設計,日本當地之客服維運中心。
# 台灣分公司:日本手機租賃服務/電子商務。</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/10u7bork?jobsource=checkc#info06" target="_blank">工作機會 (1)</a>
# </div>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="10u7bork" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="10u7bork" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/7cu180w?jobsource=checkc" target="_blank" title="&lt;嘉信資訊科技股份有限公司&gt;">嘉信資訊科技股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：4億</span>，<span>員工人數：100人</span>
# </p>
# <p class="desc">　　嘉信資訊科技股份有限公司 創立於民國 85 年，主要從事通訊網路科技業；擁有為數不少的客戶群。
#
# 　　本公司擁有優秀的經營團隊，秉持著『為客戶提供最頂尖的通訊網路解決方案』的經營理念，追求企業永續經營及成長；除整體...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/7cu180w?jobsource=checkc#info06" target="_blank">工作機會 (12)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/6000/16013516000/logo.gif?v=20200730174112"/>
# <button class="button act-save" data-custno="7cu180w" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="7cu180w" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/5t5p6qo?jobsource=checkc" target="_blank" title="&lt;弘諺科技股份有限公司&gt;">弘諺科技股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：4400萬元</span>，<span>員工人數：20人</span>
# </p>
# <p class="desc">本公司主要業務為電信雲端和核心網路設備、通信、電信器材及儀器買賣、通信工程承包及電信系統整合業務。主要客戶為各5G、大哥大、固網等電信業者及工研院資策會等財團法人。</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/5t5p6qo?jobsource=checkc#info06" target="_blank">工作機會 (3)</a>
# </div>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="5t5p6qo" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="5t5p6qo" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bjend?jobsource=checkc" target="_blank" title="&lt;愛訊電網科技股份有限公司&gt;">愛訊電網科技股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市中正區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：2000萬元</span>，<span>員工人數：14人</span>
# </p>
# <p class="desc">愛訊電網科技股份有限公司，成立於2014年04 月，
# 擁有軟體及系統豐富經驗的團隊，專注於商業應用軟體開發，
# 我們建立符合客戶需求的電信級解決方案和服務平台，同時為資訊安全服務與通訊平台整合的服務提供者。</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bjend?jobsource=checkc#info06" target="_blank">工作機會 (2)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/6537/130000000066537/logo.gif?v=20201231115444"/>
# <button class="button act-save" data-custno="1a2x6bjend" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bjend" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/18l7qso0?jobsource=checkc" target="_blank" title="&lt;長葆工業有限公司&gt;">長葆工業有限公司</a>
# <span class="color-gray font-s16 always-on-text">暫無工作機會，可儲存公司訂閱新工作</span>
# </h1>
# <p class="data">
# <span>台北市中山區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：6800萬元</span>，<span>員工人數：38人</span>
# </p>
# <p class="desc">長葆工業有限公司，成立於民國85年，並分為通信系統整合及綠能環保工業兩部門。
# 通信系統整合-
#       為一穩健成長之通信系統整合專業代理商，乃由一具備嫻熟電信網路通信設備及電信機房
#       工程實務經驗之工作團隊所組成...</p>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="18l7qso0" data-gtm="AO儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="18l7qso0" data-gtm="AO新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bj842?jobsource=checkc" target="_blank" title="&lt;宏康智慧股份有限公司&gt;">宏康智慧股份有限公司</a>
# <span class="color-gray font-s16 always-on-text">暫無工作機會，可儲存公司訂閱新工作</span>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：1000萬元</span>，<span>員工人數：30人</span>
# </p>
# <p class="desc">公司成立宗旨
# 宏康智慧是鴻海集團亞太電信與在電信資訊服務深耕25年之康維爾資訊在103年共同出資而成立。為一群為施展個人專業技術理想抱負的人員所組成，工作熱忱及敬業樂業為動力，蓬勃朝氣及人才培養為特色，勇於接受挑戰負責...</p>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/8066/130000000058066/logo.gif?v=20200730174358"/>
# <button class="button act-save" data-custno="1a2x6bj842" data-gtm="AO儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bj842" data-gtm="AO新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bibv1?jobsource=checkc" target="_blank" title="&lt;凱勝電訊有限公司&gt;">凱勝電訊有限公司</a>
# </h1>
# <p class="data">
# <span>台北市大安區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：暫不提供</span>
# </p>
# <p class="desc">1.成立於1998年.
# 2.為美國Vocom在台灣子公司, 台灣二類電信廠商.
# 3.營業項目: 國際頻寬(語音及數據)及國際海纜業務,IDC機房租賃業務,光纜產品銷售, WiFi分享器及SIM卡租賃及銷售, IoT eSIM相關產品.
# 4.總公司在美國LA,在台北,深圳...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bibv1?jobsource=checkc#info06" target="_blank">工作機會 (2)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/6269/130000000016269/logo.jpg?v=20200730174330"/>
# <button class="button act-save" data-custno="1a2x6bibv1" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bibv1" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/15btev1s?jobsource=checkc" target="_blank" title="&lt;德駏股份有限公司&gt;">德駏股份有限公司</a>
# <span class="color-gray font-s16 always-on-text">暫無工作機會，可儲存公司訂閱新工作</span>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：5300萬元</span>，<span>員工人數：23人</span>
# </p>
# <p class="desc">人們對於媒體、資訊及通訊的需求快速地成長; 唯有互動式寬頻網路才能滿足多方的需求. 30年以來，德駏公司由初始的HFC的設備，逐步跟著產業與時精進，目前更精於頭端數位與寬頻訊號的建置與優化，在系統除錯和提高整體效能上有深厚...</p>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="15btev1s" data-gtm="AO儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="15btev1s" data-gtm="AO新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/ckgww3k?jobsource=checkc" target="_blank" title="&lt;德瑪科技股份有限公司&gt;">德瑪科技股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：5000萬元</span>，<span>員工人數：30人</span>
# </p>
# <p class="desc">德瑪科技為美商亞美亞太股份有限公司台灣分公司認可之授權鑽石級合作夥伴，主要代理銷售世界頂級品牌Avaya網路式交換機系統、統一通訊系統、協同作業系統、客服中心系統、視訊系統、網路設備及週邊相關產品。
#
# 我們結合了專業且...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/ckgww3k?jobsource=checkc#info06" target="_blank">工作機會 (3)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/0000/27359120000/logo.gif?v=20200730185607"/>
# <button class="button act-save" data-custno="ckgww3k" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="ckgww3k" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bl297?jobsource=checkc" target="_blank" title="&lt;英屬開曼群島商科絡達股份有限公司台灣分公司&gt;">英屬開曼群島商科絡達股份有限公司台灣分公司</a>
# </h1>
# <p class="data">
# <span>台北市松山區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：8000萬元</span>，<span>員工人數：80人</span>
# </p>
# <p class="desc">科絡達 Carota Inc.成立於2011年，由聯發科(MediaTek)、趨勢科技(Trend Micro，全球領先安全解決方案商)和新加坡電信(Singtel，亞洲最大跨國運營商)共同合資，為跨國性的智能軟體公司，主要研發OTA(Over the Air)空中升級技術解決...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bl297?jobsource=checkc#info06" target="_blank">工作機會 (4)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/3787/130000000143787/logo.png?v=20201117155611"/>
# <button class="button act-save" data-custno="1a2x6bl297" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bl297" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bjusw?jobsource=checkc" target="_blank" title="&lt;乙鈦商業科技有限公司&gt;">乙鈦商業科技有限公司</a>
# </h1>
# <p class="data">
# <span>台北市大安區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：6人</span>
# </p>
# <p class="desc">本公司創立已二十年以上，專精通訊、資訊弱電系統領域，以不斷吸收鑽研新技術及保持一貫優良的銷售服務為後盾，並以客戶實際需求為導向，提供完善及實用的系統規劃為目標，時時督促自己並採用最新科技產品，期使能保持在業內領先...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bjusw?jobsource=checkc#info06" target="_blank">工作機會 (1)</a>
# </div>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="1a2x6bjusw" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bjusw" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/10zmqhuo?jobsource=checkc" target="_blank" title="&lt;台灣羅德史瓦茲有限公司(ROHDE&amp;SCHWARZ)&gt;">台灣羅德史瓦茲有限公司(ROHDE&amp;SCHWARZ)</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：4200萬元</span>，<span>員工人數：80人</span>
# </p>
# <p class="desc">■ 高科技與創新
# 一個高科技的企業必須藉由不斷的創新來成長茁壯。
# 超過85年集團經驗，羅德史瓦茲(Rohde &amp; Schwarz, R&amp;S)以堅實的品質與創新的技術提供了無線通訊量測、聲音影像廣播系統、安全通訊設備系統與無線電通訊監測及定...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/10zmqhuo?jobsource=checkc#info06" target="_blank">工作機會 (2)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/8000/80518668000/logo.png?v=20201201161258"/>
# <button class="button act-save" data-custno="10zmqhuo" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="10zmqhuo" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bjucg?jobsource=checkc" target="_blank" title="&lt;天尚科技有限公司&gt;">天尚科技有限公司</a>
# </h1>
# <p class="data">
# <span>台北市南港區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：4人</span>
# </p>
# <p class="desc">零食不定時供應!!!
# 邊做邊聽音樂?可以!只要不妨礙他人你開心就好..
# ​​​​​​​吃吃零食?可以!別吃到滿地又不清潔就好...
# 我們是小公司，但我們重視每一位員工，除了有良好工作環境、也提供學習及成長的空間，歡迎優秀及愛聽音樂的...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bjucg?jobsource=checkc#info06" target="_blank">工作機會 (4)</a>
# </div>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="1a2x6bjucg" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bjucg" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/b6oph0w?jobsource=checkc" target="_blank" title="&lt;Migo_熱鬧點科技有限公司&gt;">Migo_熱鬧點科技有限公司</a>
# </h1>
# <p class="data">
# <span>台北市大安區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：100人</span>
# </p>
# <p class="desc">Migo 熱鬧點科技是一間外資新創企業，全球研發暨營運總部位於台北，打造專為全球新興市場的消費者數位內容平台，計畫從東南亞地區出發。
#
# 在Migo，你所設計開發的產品，將提供新興國家數百萬名使用者，娛樂以及教育資訊的全新體驗...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/b6oph0w?jobsource=checkc#info06" target="_blank">工作機會 (4)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/2000/24348902000/logo.png?v=20201120135107"/>
# <button class="button act-save" data-custno="b6oph0w" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="b6oph0w" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/d1j3w8o?jobsource=checkc" target="_blank" title="&lt;宜泓科技有限公司&gt;">宜泓科技有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：20人</span>
# </p>
# <p class="desc">成立時間 ：西元2006年
# 經營據點 ：總部設於台北
# 國內門市 ：共2個 -台北、新竹
# 經營理念 ：本公司成立於民國95年.是專門租賃/買賣/維修大型多功能彩色/黑白事務複合機的公司.目前於台北/中壢/新竹皆有服務據點.以服務新竹以北之...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/d1j3w8o?jobsource=checkc#info06" target="_blank">工作機會 (3)</a>
# </div>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="d1j3w8o" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="d1j3w8o" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/wc316ns?jobsource=checkc" target="_blank" title="&lt;大智資訊科技股份有限公司&gt;">大智資訊科技股份有限公司</a>
# <span class="color-gray font-s16 always-on-text">暫無工作機會，可儲存公司訂閱新工作</span>
# </h1>
# <p class="data">
# <span>台北市中正區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：2800萬元</span>，<span>員工人數：58人</span>
# </p>
# <p class="desc">　　大智資訊科技股份有限公司 創立於民國 88 年，主要從事自動化系統整合&amp;TFT-LCD設備&amp;物流設備維修；本公司擁有優秀的經營團隊，秉持著『專業、迅速、熱誠、服務』的經營理念，追求企業永續經營及成長；除整體營運穩定外，獲利...</p>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="wc316ns" data-gtm="AO儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="wc316ns" data-gtm="AO新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/wd7691c?jobsource=checkc" target="_blank" title="&lt;台灣大哥大文山興隆特約門市_全首通信有限公司&gt;">台灣大哥大文山興隆特約門市_全首通信有限公司</a>
# </h1>
# <p class="data">
# <span>台北市文山區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：暫不提供</span>
# </p>
# <p class="desc">本公司是成立13年的台哥大特約門市,從事通訊商品之銷售及服務</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/wd7691c?jobsource=checkc#info06" target="_blank">工作機會 (3)</a>
# </div>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="wd7691c" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="wd7691c" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/b95165s?jobsource=checkc" target="_blank" title="&lt;威潤科技股份有限公司&gt;">威潤科技股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：3億2974萬元</span>，<span>員工人數：92人</span>
# </p>
# <p class="desc">成立時間：西元2010年。
# 經營據點：總部設於台北。於美國加州設有子公司，日本東京設有辦事處。
#
# 車聯網概念股威潤科技於2010年成立，成立短短5年即於2015年順利上櫃，為台灣唯一上櫃掛牌的衛星定位監控器製造商，市場經營成效顯...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/b95165s?jobsource=checkc#info06" target="_blank">工作機會 (20)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/4000/24497254000/logo.gif?v=20201224132803"/>
# <button class="button act-save" data-custno="b95165s" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="b95165s" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/b610i8g?jobsource=checkc" target="_blank" title="&lt;匯仲實業有限公司&gt;">匯仲實業有限公司</a>
# <span class="color-gray font-s16 always-on-text">暫無工作機會，可儲存公司訂閱新工作</span>
# </h1>
# <p class="data">
# <span>台北市松山區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：暫不提供</span>，<span>員工人數：暫不提供</span>
# </p>
# <p class="desc">我們重視每一位員工，除了有良好工作環境、也提供學習及成長的空間，歡迎優秀的朋友一起加入的工作行列。
#
#
#
# </p>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="b610i8g" data-gtm="AO儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="b610i8g" data-gtm="AO新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/ck5bky8?jobsource=checkc" target="_blank" title="&lt;毅通網絡股份有限公司&gt;">毅通網絡股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>電信相關業</span>
# </p>
# <p class="data">
# <span>資本額：1000萬元</span>，<span>員工人數：40人</span>
# </p>
# <p class="desc">毅通網絡股份有限公司為同業領導，客戶數量為同業第一，公司具備多年且豐富之網際網路相關軟硬體產品及網際網路加值型服務營業經驗。在網路時代，我們多元整合服務資訊及通訊技術。毅通網絡始終秉持『優化客戶資訊環境、提供最佳...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/ck5bky8?jobsource=checkc#info06" target="_blank">工作機會 (11)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/0000/27339650000/logo.gif?v=20200730185607"/>
# <button class="button act-save" data-custno="ck5bky8" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="ck5bky8" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bkxyr?jobsource=checkc" target="_blank" title="&lt;川升股份有限公司&gt;">川升股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>通訊機械器材相關業</span>
# </p>
# <p class="data">
# <span>資本額：1500萬元</span>，<span>員工人數：9人</span>
# </p>
# <p class="desc">川升(BWant)成立於2012年初，公司願景為"讓天線成為台灣名產"。
# 是一家以無線通訊量測服務、系統整合及創新研發的台灣企業， 以超過十年的天線開發實務經驗為基礎，結合國際大廠之量測儀器，針對工程研發及生產無線通訊產品實務應...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bkxyr?jobsource=checkc#info06" target="_blank">工作機會 (4)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/8227/130000000138227/logo.jpg?v=20200730174524"/>
# <button class="button act-save" data-custno="1a2x6bkxyr" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bkxyr" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bjvus?jobsource=checkc" target="_blank" title="&lt;點點數位股份有限公司&gt;">點點數位股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市中山區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：500萬元</span>，<span>員工人數：3人</span>
# </p>
# <p class="desc">Tapgo試著提供環境給：
# 1. 厭倦了在大公司只專注在某一個小小領域，渴望接觸外界各式各樣技術的您
# 2. 期待不受外界干擾，而進一步追求技術卓越的您
# 3. 有點年紀，擁有一身好技藝但是不被外面所謂的＂新創公司＂接受的您
# 4. 以...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bjvus?jobsource=checkc#info06" target="_blank">工作機會 (7)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/8836/130000000088836/logo.gif?v=20201210002443"/>
# <button class="button act-save" data-custno="1a2x6bjvus" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bjvus" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bk28n?jobsource=checkc" target="_blank" title="&lt;香港商尚域投資有限公司台灣分公司&gt;">香港商尚域投資有限公司台灣分公司</a>
# </h1>
# <p class="data">
# <span>台北市內湖區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：100萬元</span>，<span>員工人數：暫不提供</span>
# </p>
# <p class="desc">關於vivo
# vivo為一個專注於智慧手機領域的手機領導品牌，vivo和追求樂趣、充滿活力、年輕時尚的族群一起打造擁有卓越外觀、專業級音質、極致影像、愉快體驗的智慧產品，並勇敢於追求極致、持續創造驚喜作為vivo的堅定理想追求。
# ...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bk28n?jobsource=checkc#info06" target="_blank">工作機會 (14)</a>
# </div>
# </div>
# <div class="action">
# <img alt="" class="logo" src="https://static.104.com.tw/b_profile/cust_picture/7111/130000000097111/logo.jpg?v=20200826162022"/>
# <button class="button act-save" data-custno="1a2x6bk28n" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bk28n" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# <article class="items">
# <div class="info">
# <h1>
# <a href="https://www.104.com.tw/company/1a2x6bjr9h?jobsource=checkc" target="_blank" title="&lt;三傑物聯科技股份有限公司&gt;">三傑物聯科技股份有限公司</a>
# </h1>
# <p class="data">
# <span>台北市信義區</span>，<span>其他電信及通訊相關業</span>
# </p>
# <p class="data">
# <span>資本額：1億</span>，<span>員工人數：16人</span>
# </p>
# <p class="desc">公司創立於民國105年
# 主要從事無線物聯網業，擁有為數不少的客戶群。
# 本公司擁有優秀的經營團隊，秉持著「創新及服務」的經營理念，追求企業永續經營成長。
# 我們重視每一位員工，有良好工作環境，也提供學習及成長空間，歡迎優秀...</p>
# <div class="jobs">
# <a href="https://www.104.com.tw/company/1a2x6bjr9h?jobsource=checkc#info06" target="_blank">工作機會 (3)</a>
# </div>
# </div>
# <div class="action">
# <button class="button act-save" data-custno="1a2x6bjr9h" data-gtm="正常儲存公司" title="儲存公司" type="button">
# <i class="jbi-s18-star-dark"></i> 儲存公司                </button>
# <button class="button act-notice" data-custno="1a2x6bjr9h" data-gtm="正常新工作通知" title="新工作通知" type="button">
# <i class="jbi-s18-check-dark"></i> 新工作通知                </button>
# </div>
# <div class="clearfix"></div>
# </article>
# </div>
# </div>
# <div id="company-similar"></div>
# <!-- 頁碼 start -->
# <div id="company-pages">
# <div class="page-frg">
# <div class="page-ctrl">
# <a class="page-prev disabled">上一頁</a><a class="page-num active" data-value="1" href="/cust/list/index?page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">1</a><a class="page-num" data-value="2" href="/cust/list/index?page=2&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">2</a><a class="page-num" data-value="3" href="/cust/list/index?page=3&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">3</a><a class="page-num" data-value="4" href="/cust/list/index?page=4&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">4</a><a class="page-num" data-value="5" href="/cust/list/index?page=5&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">5</a><a class="page-num" data-value="6" href="/cust/list/index?page=6&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">6</a><a class="page-num" data-value="7" href="/cust/list/index?page=7&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">7</a><a class="page-num" data-value="8" href="/cust/list/index?page=8&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">8</a><a class="page-next" href="/cust/list/index?page=2&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">下一頁</a> </div>
# <div class="page-total" data-total="8">共 8 頁</div>
# </div>
# </div>
# <!-- 頁碼 end -->
# </div>
# </main>
# <aside class="aside">
# <section class="block history">
# <h2>最近查詢紀錄：</h2>
# <span class="latest" title="台北市、電信及通訊相關業">台北市、電信及通訊相關業<span class="angle-down"></span></span>
# <div class="dialog-layer arrow-top" id="search-history">
# <div class="dl-arrow">
# <div class="dl-arwout"></div>
# <div class="dl-arwin"></div>
# </div>
# <div class="dl-content">
#                       	 最近查詢記錄：
#                         <ul class="sh-record"><li><a href="/cust/list/index/?page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc" title="台北市、電信及通訊相關業">台北市、電信及通訊相關業</a></li></ul>
# <div class="del"><button class="button text act-del" onclick="javascript:clearHistoryLogs('cCondi');return false;" type="button">清除查詢紀錄<span class="jbi-s15-delete-red"></span></button></div>
# <button class="button text act-close" title="關閉" type="button"><span class="jbi-s15-close-small"></span></button>
# </div>
# </div>
# </section>
# <!-- filter start -->
# <section class="block filter">
# <h2>調整查詢結果</h2>
# <section class="fold-list" data-max="1" id="company-status">
# <h3 class="type">
# 					徵才狀態<span class="jbi-s15-minus"></span>
# </h3>
# <ul class="list"><li data-gtm="filter" data-value="3"><a href="/cust/list/index?sw=3&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">廣告刊登中</a></li><li data-gtm="filter" data-value="2"><a href="/cust/list/index?sw=2&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">不拘</a></li></ul>
# </section><section class="fold-list" data-max="1" id="company-welfare">
# <h3 class="type">
# 					福利制度<span class="jbi-s15-minus"></span>
# </h3>
# <ul class="list"><li data-gtm="filter" data-value="1"><a href="/cust/list/index?wf=1&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">年終獎金</a></li><li data-gtm="filter" data-value="2"><a href="/cust/list/index?wf=2&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">三節獎金/禮品</a></li><li data-gtm="filter" data-value="3"><a href="/cust/list/index?wf=3&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">員工旅遊</a></li><li data-gtm="filter" data-value="4"><a href="/cust/list/index?wf=4&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">分紅配股</a></li><li data-gtm="filter" data-value="5"><a href="/cust/list/index?wf=5&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">設施類福利</a></li><li data-gtm="filter" data-value="6"><a href="/cust/list/index?wf=6&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">休假福利</a></li><li data-gtm="filter" data-value="7"><a href="/cust/list/index?wf=7&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">津貼/補助</a></li><li data-gtm="filter" data-value="8"><a href="/cust/list/index?wf=8&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">彈性上下班</a></li><li data-gtm="filter" data-value="9"><a href="/cust/list/index?wf=9&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">健康檢查</a></li><li data-gtm="filter" data-value="10"><a href="/cust/list/index?wf=10&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">團體保險</a></li></ul>
# </section><section class="fold-list" data-max="1" id="company-employee">
# <h3 class="type">
# 					員工人數<span class="jbi-s15-minus"></span>
# </h3>
# <ul class="list"><li data-gtm="filter" data-value="1"><a href="/cust/list/index?emp=1&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">4人以下</a></li><li data-gtm="filter" data-value="2"><a href="/cust/list/index?emp=2&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">5-9人</a></li><li data-gtm="filter" data-value="3"><a href="/cust/list/index?emp=3&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">10-29人</a></li><li data-gtm="filter" data-value="4"><a href="/cust/list/index?emp=4&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">30-49人</a></li><li data-gtm="filter" data-value="5"><a href="/cust/list/index?emp=5&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">50-99人</a></li><li data-gtm="filter" data-value="6"><a href="/cust/list/index?emp=6&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">100-249人</a></li><li data-gtm="filter" data-value="7"><a href="/cust/list/index?emp=7&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">250-499人</a></li><li data-gtm="filter" data-value="8"><a href="/cust/list/index?emp=8&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">500人以上</a></li></ul>
# </section><section class="fold-list" data-max="1" id="company-capital">
# <h3 class="type">
# 					資本額<span class="jbi-s15-minus"></span>
# </h3>
# <ul class="list"><li data-gtm="filter" data-value="1"><a href="/cust/list/index?cpt=1&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">100萬以下</a></li><li data-gtm="filter" data-value="2"><a href="/cust/list/index?cpt=2&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">101-500萬</a></li><li data-gtm="filter" data-value="3"><a href="/cust/list/index?cpt=3&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">501-1000萬</a></li><li data-gtm="filter" data-value="4"><a href="/cust/list/index?cpt=4&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">1001-3000萬</a></li><li data-gtm="filter" data-value="5"><a href="/cust/list/index?cpt=5&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">3001-5000萬</a></li><li data-gtm="filter" data-value="6"><a href="/cust/list/index?cpt=6&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">5000萬-1億</a></li><li data-gtm="filter" data-value="7"><a href="/cust/list/index?cpt=7&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">1-10億</a></li><li data-gtm="filter" data-value="8"><a href="/cust/list/index?cpt=8&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">10-100億</a></li><li data-gtm="filter" data-value="9"><a href="/cust/list/index?cpt=9&amp;page=1&amp;area=6001001000&amp;indcat=1001002000&amp;order=1&amp;mode=s&amp;jobsource=checkc">100億以上</a></li></ul>
# </section> </section>
# <!-- filter end -->
# </aside>
# <div class="clearfix"></div>
# </div>
# <div id="divorg"></div><div class="dialog-layer arrow-right act-msg" style="display: none;"><div class="dl-arrow hcenter"><div class="dl-arwout"></div><div class="dl-arwin"></div></div><div class="dl-content"></div></div>
# <div id="search-fix">
# <!--看儲存工作、go top START-->
# <ul class="tool-area b-fixed-right side-tools">
# <li>
# <a href="https://pda.104.com.tw/forward.cfm?fun_code=17dpwyehax" target="_blank">
# <svg class="icon-star b-icon--weak-gray b-icon--w24">
# <path d="M18.393 13.427a2.13 2.13 0 0 0-.573 1.836l.71 4.307c.22 1.341-.803 2.43-1.963 2.43-.306 0-.622-.076-.928-.243l-3.712-2.034a1.933 1.933 0 0 0-1.854 0l-3.712 2.034a1.922 1.922 0 0 1-.928.243c-1.16 0-2.183-1.089-1.962-2.43l.71-4.307a2.13 2.13 0 0 0-.574-1.836l-3.004-3.05c-1.181-1.2-.529-3.292 1.104-3.54l4.151-.627a1.996 1.996 0 0 0 1.5-1.136l1.856-3.918C9.58.385 10.29 0 11 0c.711 0 1.422.385 1.787 1.156l1.857 3.918c.289.613.85 1.038 1.499 1.136l4.151.628c1.633.247 2.285 2.338 1.104 3.538l-3.004 3.05z" fill-rule="evenodd"></path>
# </svg>
# <span>儲存清單</span>
# </a>
# </li>
# <li>
# <a class="b-icon b-hide" href="#" id="js-go-top" style="display: none;">
# <svg class="icon-go-top b-icon--weak-gray b-icon--w24">
# <path d="M17.675 11.498a1.197 1.197 0 0 1-.849.352c-.288 0-.57-.113-.799-.32l-.008.01-2.793-2.792v9.053a1.199 1.199 0 1 1-2.4 0V8.698l-2.842 2.841-.01-.008a1.19 1.19 0 0 1-.798.319 1.199 1.199 0 0 1-.848-2.048l4.186-4.187c.41-.41.948-.616 1.486-.616.54 0 1.078.205 1.488.616l4.187 4.187c.469.468.469 1.227 0 1.696M12 0C5.374 0 0 5.374 0 12c0 6.628 5.374 12 12 12 6.629 0 12-5.372 12-12 0-6.626-5.371-12-12-12" fill-rule="evenodd"></path>
# </svg>
# <span>回到頂部</span>
# </a>
# </li>
# </ul>
# <!--看儲存工作、go top、我要回饋 END-->
# </div>
# <footer id="ft-thin">
# <div class="bar">
# <button class="button text cs" type="button">
# <span class="jbi-s18-tel"></span>104 客服
# 		</button>
# <div class="dialog-layer arrow-bottom" id="custom-service">
# <div class="dl-arrow">
# <div class="dl-arwout"></div>
# <div class="dl-arwin"></div>
# </div>
# <button class="button text dl-close" title="關閉">
# <span class="jbi-s15-close-small"></span>
# </button>
# <div class="dl-content">
# <div class="char user">
# <div class="identify">
# <span class="jbi-s18-user"></span>我是求職者
# 					</div>
# <div class="contact">
# <dl>
# <dt>求職服務專線</dt>
# <dd>02-2912-6104 轉2</dd>
# </dl>
# <div class="mail">
# <a href="https://www.104.com.tw/question_admin/reaction.cfm" target="_blank"><span class="jbi-s18-mail"></span>求職客服信箱</a>
# </div>
# <div class="safety">
# <a href="javascript:void(0)" onclick="window.open('https://www.104.com.tw/public/pda/pop_safety.htm','','scrollbars=yes,width=500,height=480')"><span class="jbi-s15-care"></span>職場安全諮詢專線</a>
# </div>
# </div>
# </div>
# <div class="char company">
# <div class="identify">
# <span class="jbi-s18-building"></span>我是求才廠商
# 					</div>
# <div class="contact">
# <dl>
# <dt>廠商求才專線</dt>
# <dd>
# <ul>
# <li>台北 02-2912-6104</li>
# <li>台中 04-3700-6104</li>
# <li>上海 86-21-50277104 轉1</li>
# </ul>
# </dd>
# </dl>
# <div class="mail">
# <a href="https://www.104.com.tw/redirect/vip_message.htm" target="_blank"><span class="jbi-s18-mail"></span>求才客服信箱</a>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="time">服務時間：週一至週五9:00~19:00</div>
# </div>
# </div>
# <a class="tel" href="javascript:void(0)" onclick="window.open('https://www.104.com.tw/public/pda/pop_safety.htm','','scrollbars=yes,width=500,height=480')"><span class="jbi-s15-care"></span>職場安全諮詢專線</a>
# <div class="clearfix"></div>
# </div>
# <div class="copyright">
# 		104 人力銀行網站由一零四資訊股份有限公司創設。建議瀏覽器版本為 IE11.0 以上<br/>本網站內容享有著作權，禁止侵害，違者必究。 © 2021 104 Corporation All Rights Reserved.
# 	</div>
# </footer>
# <!-- Start Alexa Certify Javascript -->
# <script type="text/javascript">
# _atrk_opts = { atrk_acct:"lRlHh1awVK00wf", domain:"104.com.tw",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
# </script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=lRlHh1awVK00wf" style="display:none" width="1"/></noscript>
# <!-- End Alexa Certify Javascript --> <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/frame.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://www.104.com.tw/public/area/AutoSuggest/AutoSuggest.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/search/company-suggestion.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/search/historyLogs.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/SharedObjectAPI.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://www.104.com.tw/public/function01/utf8/jsonIndust.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://www.104.com.tw/public/function01/utf8/jsonArea.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://www.104.com.tw/public/function01/menu/js/e104menu2011.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/lib/jquery.history.js" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/lib/react-with-addons.min.js" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/nccLog.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/ui/image-error.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/ui/fold-list.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/ui/company-action.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/react_compiled/company-summary.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/react_compiled/company-list.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/react_compiled/similar-company.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/react_compiled/page-fragment.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/search/company-catemenu.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://static.104.com.tw/104main/jb/js/search/company.js?v=20170330" type="text/javascript"></script>
# <script charset="UTF-8" src="https://aidma.104.com.tw/js/e104aidma.php?wid=2&amp;cid=8" type="text/javascript"></script>
# <script charset="UTF-8" type="text/javascript">
# /*<![CDATA[*/
# e104aidma_show('aidma_130',2,8,130,false,true);var chkAd = e104aidma_checkBoardIsDefault(130);if(chkAd == 1 || chkAd == 2){ e104aidma_show('aidma_134',2,8,134,false,true); }else{ $('#hd-min .ad-box.text').hide(); }
# 		<!-- Google Tag Manager -->
# 		(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push(
#
# 		{'gtm.start': new Date().getTime(),event:'gtm.js'}
# 		);var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-P379T3');
# 		<!-- End Google Tag Manager -->
#
# /*]]>*/
# </script>
# <script id="" type="text/javascript">_atrk_opts={atrk_acct:"lRlHh1awVK00wf",domain:"104.com.tw",dynamic:!0};(function(){var a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://d31qbv1cthcecs.cloudfront.net/atrk.js";var b=document.getElementsByTagName("script")[0];b.parentNode.insertBefore(a,b)})();</script>
# <noscript><img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=lRlHh1awVK00wf" style="display:none" width="1"/></noscript>
# <script id="" src="https://www.googletagmanager.com/gtag/js?id=AW-968874231" type="text/javascript"></script>
# <script id="" type="text/javascript">window.dataLayer=window.dataLayer||[];function gtag(){dataLayer.push(arguments)}gtag("js",new Date);gtag("config","AW-968874231");</script>
# <script id="" type="text/javascript">if("undefined"===typeof elog||null===elog)var _elog=_elog||[];_elog.push({web:"104_bank",track:["viewPage"],ext:{gcid:"1470400561.1609601576"}});
# (function(){if("undefined"===typeof b||null===b){var a="\/\/static.104.com.tw\/104i",b=document.createElement("script");b.type="text/javascript";b.id="logjsapi";b.async=!0;b.src=a+"/js/api/log/e104.log.latest.js?v\x3d20201028";var c=[];b.onreadystatechange=function(){c.push(this.readyState);if("loaded"===this.readyState&&!Array.prototype.indexOf){var d=/interactive/;d.test(c.join(","))||_elog[0]&&_elog[0].callback&&"function"===typeof _elog[0].callback&&_elog[0].callback.call(this)}};b.onerror=function(){_elog[0]&&
# _elog[0].callback&&"function"===typeof _elog[0].callback&&_elog[0].callback.call(this)};a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(b,a)}})();
# "undefined"===typeof cache_e104aidma_click&&"undefined"!==typeof e104aidma_click&&(cache_e104aidma_click=e104aidma_click,e104aidma_click=function(a){cache_e104aidma_click(a);console.log("rew");a=a.split(",");a={webId:a[1],channelId:a[2],boardId:a[3],specType:a[4],specId:a[5],targetUrl:a[6],gcid:"1470400561.1609601576"};_elog=_elog||[];_elog.push({web:"104_bank",track:["clickBanner"],ext:a});dataLayer.push({event:"eventGetAidma",eventCategory:"ClickAidma",eventAction:a.channelId,eventLabel:a.boardId+
# "_"+a.specId})});</script></body></html>
