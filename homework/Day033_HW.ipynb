# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）

# %%
import requests 
from bs4 import BeautifulSoup 
#res = requests.get("https://github.com/new",verify=False)
#soup = BeautifulSoup(res.text,"html.parser")
#print(soup.text)

res = requests.get("https://github.com/new",verify=False,cookies={"dotcom_user":"pacy350217","user_session":"c870gz4Iqwv_taaflR6fC8nS4Ocknp5A5lzEEhZWVeAkALum","logged_in":"yes","__Host-user_session_same_site":"c870gz4Iqwv_taaflR6fC8nS4Ocknp5A5lzEEhZWVeAkALum"})
soup = BeautifulSoup(res.text,"html.parser")
print(soup.text)
# Out:
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'github.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Create a New Repository
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
# No suggested jump to results
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Search
#
#
#         All GitHub
#
# ↵
#
#
#       Jump to
#       ↵
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         Dashboard
#
#
#         Pull requests
#
#
#       Issues
#
#
#
#           Marketplace
#
#
#       Explore
#
#
#       Settings
#
#
#
#       pacy350217
#
#
#
#
#         Sign out
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   New repository
#
#
#     Import repository
#
#
#   New gist
#
#
#     New organization
#
#
#     New project
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Sorry, something went wrong.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Create a new repository
#
#       A repository contains all project files, including the revision history.
#
#         Already have a project repository elsewhere? Import a repository.
#
#
#
#
# Owner
#
#
#
#
#
#
#     pacy350217
#
#
#
#
#
#
#
#
#
#       pacy350217
#
#
#
#
#
#
#
# /
#
#
# Repository name
#
#
#
#
#
#
#         You found a secret! pacy350217/pacy350217
#         is a ✨special ✨ repository that you can use
#         to add a README.md to your GitHub profile. Make sure
#         it’s public and initialize it with a README to
#         get started.
#
#
#
#
#         Great repository names are short and memorable. Need inspiration? How about
#         studious-engine?
#
#
# Description (optional)
#
#
#
#
#
#             Public
#
#
#
#               Anyone on the internet can see this repository. You choose who can commit.
#
#
#             You may not create public repositories by organization policy.
#
#
#
#
#
#           Private
#
#
#
#           You choose who can see and commit to this repository.
#
#
#           You may not create private repositories by organization policy.
#
#
#           We are unable to provide access to GitHub private repository services.
# It appears your account may be based in a U.S.-sanctioned region. As a result, due to U.S. trade controls law restrictions, we are unable to provide private repository services and paid services for your account. GitHub has preserved, however, your access to certain free services for public repositories.
# If your account has been flagged in error, and you are not located in or resident in a sanctioned region, please file an appeal. Please read about GitHub and Trade Controls for more information.
#
#
#           We are unable to provide access to GitHub private repository services.
# It appears your account may be based in a U.S.-sanctioned region. As a result, due to U.S. trade controls law restrictions, we are unable to provide private repository services and paid services for your account. GitHub has preserved, however, your access to certain free services for public repositories.
# If your account has been flagged in error, and you are not located in or resident in a sanctioned region, please file an appeal. Please read about GitHub and Trade Controls for more information.
#
#
#           Your current plan does not support private repositories.
#
#               Your organization's owners will need to upgrade to Team.
#
#
#
#
#
#
#
#
#
# Initialize this repository with:
# Skip this step if you’re importing an existing repository.
#
#
#
#
#             Add a README file
#
#
#             This is where you can write a long description for your project.
#             Learn more.
#
#
#
#
#
#             Add .gitignore
#
#
#             Choose which files not to track from a list of templates.
#             Learn more.
#
#
#
#
# .gitignore template:
# None
#
#
#
# .gitignore template
#
#
#
#
#
#
#
#
#
#
#
# None
#
#
#
#
# Actionscript
#
#
#
#
# Ada
#
#
#
#
# Agda
#
#
#
#
# Android
#
#
#
#
# AppEngine
#
#
#
#
# AppceleratorTitanium
#
#
#
#
# ArchLinuxPackages
#
#
#
#
# Autotools
#
#
#
#
# C
#
#
#
#
# C++
#
#
#
#
# CFWheels
#
#
#
#
# CMake
#
#
#
#
# CUDA
#
#
#
#
# CakePHP
#
#
#
#
# ChefCookbook
#
#
#
#
# Clojure
#
#
#
#
# CodeIgniter
#
#
#
#
# CommonLisp
#
#
#
#
# Composer
#
#
#
#
# Concrete5
#
#
#
#
# Coq
#
#
#
#
# CraftCMS
#
#
#
#
# D
#
#
#
#
# DM
#
#
#
#
# Dart
#
#
#
#
# Delphi
#
#
#
#
# Drupal
#
#
#
#
# EPiServer
#
#
#
#
# Eagle
#
#
#
#
# Elisp
#
#
#
#
# Elixir
#
#
#
#
# Elm
#
#
#
#
# Erlang
#
#
#
#
# ExpressionEngine
#
#
#
#
# ExtJs
#
#
#
#
# Fancy
#
#
#
#
# Finale
#
#
#
#
# ForceDotCom
#
#
#
#
# Fortran
#
#
#
#
# FuelPHP
#
#
#
#
# GWT
#
#
#
#
# GitBook
#
#
#
#
# Go
#
#
#
#
# Godot
#
#
#
#
# Gradle
#
#
#
#
# Grails
#
#
#
#
# Haskell
#
#
#
#
# IGORPro
#
#
#
#
# Idris
#
#
#
#
# JENKINS_HOME
#
#
#
#
# Java
#
#
#
#
# Jboss
#
#
#
#
# Jekyll
#
#
#
#
# Joomla
#
#
#
#
# Julia
#
#
#
#
# KiCAD
#
#
#
#
# Kohana
#
#
#
#
# Kotlin
#
#
#
#
# LabVIEW
#
#
#
#
# Laravel
#
#
#
#
# Leiningen
#
#
#
#
# LemonStand
#
#
#
#
# Lilypond
#
#
#
#
# Lithium
#
#
#
#
# Lua
#
#
#
#
# Magento
#
#
#
#
# Maven
#
#
#
#
# Mercury
#
#
#
#
# MetaProgrammingSystem
#
#
#
#
# Nim
#
#
#
#
# Node
#
#
#
#
# OCaml
#
#
#
#
# Objective-C
#
#
#
#
# Opa
#
#
#
#
# OracleForms
#
#
#
#
# Packer
#
#
#
#
# Perl
#
#
#
#
# Perl6
#
#
#
#
# Phalcon
#
#
#
#
# PlayFramework
#
#
#
#
# Plone
#
#
#
#
# Prestashop
#
#
#
#
# Processing
#
#
#
#
# PureScript
#
#
#
#
# Python
#
#
#
#
# Qooxdoo
#
#
#
#
# Qt
#
#
#
#
# R
#
#
#
#
# ROS
#
#
#
#
# Rails
#
#
#
#
# RhodesRhomobile
#
#
#
#
# Ruby
#
#
#
#
# Rust
#
#
#
#
# SCons
#
#
#
#
# Sass
#
#
#
#
# Scala
#
#
#
#
# Scheme
#
#
#
#
# Scrivener
#
#
#
#
# Sdcc
#
#
#
#
# SeamGen
#
#
#
#
# SketchUp
#
#
#
#
# Smalltalk
#
#
#
#
# SugarCRM
#
#
#
#
# Swift
#
#
#
#
# Symfony
#
#
#
#
# SymphonyCMS
#
#
#
#
# TeX
#
#
#
#
# Terraform
#
#
#
#
# Textpattern
#
#
#
#
# TurboGears2
#
#
#
#
# Typo3
#
#
#
#
# Umbraco
#
#
#
#
# Unity
#
#
#
#
# UnrealEngine
#
#
#
#
# VVVV
#
#
#
#
# VisualStudio
#
#
#
#
# Waf
#
#
#
#
# WordPress
#
#
#
#
# Xojo
#
#
#
#
# Yeoman
#
#
#
#
# Yii
#
#
#
#
# ZendFramework
#
#
#
#
# Zephir
#
#
#
#
# gcov
#
#
#
#
# nanoc
#
#
#
#
# opencart
#
#
#
#
# stella
#
#
# Nothing to show
#
#
#
#
#
#
#
#
#               Choose a license
#
#
#               A license tells others what they can and can't do with your code.
#               Learn more.
#
#
#
#
#
#         License:
#
# None
#
#
#
#
# License
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       None
#
#
#
#       None
#
#
#
#
#
#
#
#       Apache License 2.0
#
#
#
#       Apache License 2.0
#
#
#
#
#
#
#
#       GNU General Public License v3.0
#
#
#
#       GNU General Public License v3.0
#
#
#
#
#
#
#
#       MIT License
#
#
#
#       MIT License
#
#
#
#
#
#
#
#       BSD 2-Clause "Simplified" License
#
#
#
#       BSD 2-Clause "Simplified" License
#
#
#
#
#
#
#
#       BSD 3-Clause "New" or "Revised" License
#
#
#
#       BSD 3-Clause "New" or "Revised" License
#
#
#
#
#
#
#
#       Boost Software License 1.0
#
#
#
#       Boost Software License 1.0
#
#
#
#
#
#
#
#       Creative Commons Zero v1.0 Universal
#
#
#
#       Creative Commons Zero v1.0 Universal
#
#
#
#
#
#
#
#       Eclipse Public License 2.0
#
#
#
#       Eclipse Public License 2.0
#
#
#
#
#
#
#
#       GNU Affero General Public License v3.0
#
#
#
#       GNU Affero General Public License v3.0
#
#
#
#
#
#
#
#       GNU General Public License v2.0
#
#
#
#       GNU General Public License v2.0
#
#
#
#
#
#
#
#       GNU Lesser General Public License v2.1
#
#
#
#       GNU Lesser General Public License v2.1
#
#
#
#
#
#
#
#       Mozilla Public License 2.0
#
#
#
#       Mozilla Public License 2.0
#
#
#
#
#
#
#
#       The Unlicense
#
#
#
#       The Unlicense
#
#
#
#               No results found.
#
#
#
#
#
#
#
#
#
#           This will set
#
#
# main
#
#           as the default branch.
#
#             Change the default name in
#
#                 your
#
# settings.
#
#
#             Contact the organization admin to change the default name.
#
#
#
#
#
#
#
#
#
#
#
#
#         Create repository
#
#
#
#
#         You don’t appear to have permission to create repositories for this organization. Sorry about that.
#
#
#
#
#
#
#
#
#
# © 2021 GitHub, Inc.
# Terms
# Privacy
# Security
# Status
# Help
#
#
#
#
#
# Contact GitHub
# Pricing
# API
# Training
# Blog
# About
#
#
#
#
#
#
#
#
#
#
#
#     You can’t perform that action at this time.
#
#
#
# You signed in with another tab or window. Reload to refresh your session.
# You signed out in another tab or window. Reload to refresh your session.

# %%
#練習
import requests 
from bs4 import BeautifulSoup 
res = requests.get("https://www.ptt.cc/bbs/Gossiping/index.html",verify=False)
soup = BeautifulSoup(res.text,"html.parser")
print(soup.text)
# Out:
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開

# %%
import requests 
from bs4 import BeautifulSoup 
res = requests.get("https://www.ptt.cc/bbs/Gossiping/index.html",verify=False)
soup = BeautifulSoup(res.text,"html.parser")

rs = requests.session()
payload = {
    "from":"/bbs/Gossiping/index.html",
    "yes":"yes"
}

res = rs.post("https://www.ptt.cc/ask/over18",verify=False,data=payload)
res = rs.get("https://www.ptt.cc/bbs/Gossiping/index.html",verify=False)
soup = BeautifulSoup(res.text,"html.parser")
print(soup.text)
# Out:
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] 有沒有車行把客人機車摔爛的八卦? (影片
#
#
# a91153456
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 a91153456 的文章
#
#
#  1/10
#
#
#
#
# 4
#
# [問卦] 遇到行車糾紛打架 是揍他吃虧還是被打吃虧?
#
#
# ThorFukt
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ThorFukt 的文章
#
#
#  1/10
#
#
#
#
# 3
#
# Re: [新聞] 科技男慘死國道！大貨車衝過分隔島將4百
#
#
# vigorhsieh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 vigorhsieh 的文章
#
#
#  1/10
#
#
#
#
# 6
#
# [問卦] 大家隨身碟的容量多大？
#
#
# flower42
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 flower42 的文章
#
#
#  1/10
#
#
#
#
#
#
# [新聞] 《星光2》葉瑋庭懷混血寶寶！「PO超音波
#
#
# goodser456
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 goodser456 的文章
#
#
#  1/10
#
#
#
#
#
#
# [問卦] 攪拌麵和醬的技巧？
#
#
# Recoverism
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Recoverism 的文章
#
#
#  1/10
#
#
#
#
#
#
# [問卦] 近視可否透過重訓改善？
#
#
# kusowan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kusowan 的文章
#
#
#  1/10
#
#
#
#
# 1
#
# Re: [問卦] 一旦發動台灣獨立建國，國軍會幫誰？
#
#
# cwh0105
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cwh0105 的文章
#
#
#  1/10
#
#
#
#
# 1
#
# [問卦] 莫彩曦大概算什麼等級的台女？
#
#
# gostjoke
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gostjoke 的文章
#
#
#  1/10
#
#
#
#
#
#
# Re: [問卦] 4%、八卦網軍今天氣到發抖？
#
#
# cutbear123
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cutbear123 的文章
#
#
#  1/10
#
#
#
#
# 4
#
# [問卦] 開哪牌的車跟大卡車對撞 存活率最高
#
#
# david0426
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 david0426 的文章
#
#
#  1/10
#
#
#
#
# 1
#
# [問卦] 天花板上幹嘛做棕色一條一條的？
#
#
# Ujdhw3425
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Ujdhw3425 的文章
#
#
#  1/10
#
#
#
#
# 2
#
# Re: [問卦] 為什麼設計系出身的大多愛用MacOS/IOS系統
#
#
# hugh509
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hugh509 的文章
#
#
#  1/10
#
#
#
#
#
#
# Re: [新聞] 家樂福嗆主動撤銷台灣豬標章 農委會急滅
#
#
# A6
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 A6 的文章
#
#
#  1/10
#
#
#
#
#
#
# [問卦] 淡水的冷會強過 西雅圖、倫敦的冷嗎?
#
#
# syearth
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 syearth 的文章
#
#
#  1/10
#
#
#
#
# 2
#
# [問卦] 世界各國哪一個大城市的人最機車？
#
#
# iphone15
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 iphone15 的文章
#
#
#  1/10
#
#
#
#
# 1
#
# [問卦] 要怎麼打蟲族母星？
#
#
# FireHawk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 FireHawk 的文章
#
#
#  1/10
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.11.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
# 11/21
# !
#
#
#
# 15
#
# [協尋] 2021/1/5 行車紀錄器 重慶南路接近衡陽
#
#
# tenth
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 tenth 的文章
#
#
#  1/05
#
#
#
#
# 5
#
# [協尋] 1/6 19：08 中市敦化中平路口 行車記錄器
#
#
# chester0312
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 chester0312 的文章
#
#
#  1/08
#
#
#
#
# 7
#
# [協尋] 找到肇事者了!感謝大家!01/07/20:00彰化秀水馬鳴路
#
#
# alittlekoa
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 alittlekoa 的文章
#
#
#  1/09
#
#
#
#
# 3
#
# Fw: [問題] 協尋一月七號晚上新莊19號越堤道行車
#
#
# lilianstarbo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lilianstarbo 的文章
#
#
#  1/09
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。

# %%
res = requests.get("https://www.ptt.cc/bbs/Gossiping/index.html",verify=False,cookies={"over18":"1"})
soup = BeautifulSoup(res.text,"html.parser")
print(soup.text)
# Out:
# /Users/Pacy/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.ptt.cc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
#
#
# [問卦] 有沒有車行把客人機車摔爛的八卦? (影片
#
#
# a91153456
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 a91153456 的文章
#
#
#  1/10
#
#
#
#
# 3
#
# [問卦] 遇到行車糾紛打架 是揍他吃虧還是被打吃虧?
#
#
# ThorFukt
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ThorFukt 的文章
#
#
#  1/10
#
#
#
#
# 4
#
# Re: [新聞] 科技男慘死國道！大貨車衝過分隔島將4百
#
#
# vigorhsieh
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 vigorhsieh 的文章
#
#
#  1/10
#
#
#
#
# 6
#
# [問卦] 大家隨身碟的容量多大？
#
#
# flower42
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 flower42 的文章
#
#
#  1/10
#
#
#
#
#
#
# [新聞] 《星光2》葉瑋庭懷混血寶寶！「PO超音波
#
#
# goodser456
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 goodser456 的文章
#
#
#  1/10
#
#
#
#
#
#
# [問卦] 攪拌麵和醬的技巧？
#
#
# Recoverism
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Recoverism 的文章
#
#
#  1/10
#
#
#
#
#
#
# [問卦] 近視可否透過重訓改善？
#
#
# kusowan
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 kusowan 的文章
#
#
#  1/10
#
#
#
#
# 1
#
# Re: [問卦] 一旦發動台灣獨立建國，國軍會幫誰？
#
#
# cwh0105
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cwh0105 的文章
#
#
#  1/10
#
#
#
#
# 2
#
# [問卦] 莫彩曦大概算什麼等級的台女？
#
#
# gostjoke
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gostjoke 的文章
#
#
#  1/10
#
#
#
#
#
#
# Re: [問卦] 4%、八卦網軍今天氣到發抖？
#
#
# cutbear123
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 cutbear123 的文章
#
#
#  1/10
#
#
#
#
# 5
#
# [問卦] 開哪牌的車跟大卡車對撞 存活率最高
#
#
# david0426
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 david0426 的文章
#
#
#  1/10
#
#
#
#
# 1
#
# [問卦] 天花板上幹嘛做棕色一條一條的？
#
#
# Ujdhw3425
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Ujdhw3425 的文章
#
#
#  1/10
#
#
#
#
# 2
#
# Re: [問卦] 為什麼設計系出身的大多愛用MacOS/IOS系統
#
#
# hugh509
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 hugh509 的文章
#
#
#  1/10
#
#
#
#
#
#
# Re: [新聞] 家樂福嗆主動撤銷台灣豬標章 農委會急滅
#
#
# A6
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 A6 的文章
#
#
#  1/10
#
#
#
#
# 1
#
# [問卦] 淡水的冷會強過 西雅圖、倫敦的冷嗎?
#
#
# syearth
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 syearth 的文章
#
#
#  1/10
#
#
#
#
# 3
#
# [問卦] 世界各國哪一個大城市的人最機車？
#
#
# iphone15
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 iphone15 的文章
#
#
#  1/10
#
#
#
#
# 3
#
# [問卦] 要怎麼打蟲族母星？
#
#
# FireHawk
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 FireHawk 的文章
#
#
#  1/10
#
#
#
#
#
#
# Re: [新聞] 美台交往限制取消　拜登陣營：落實台灣
#
#
# immengod
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 immengod 的文章
#
#
#  1/10
#
#
#
#
#
#
#
# [公告] 八卦板板規(2020.11.21)
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
# 11/21
# !
#
#
#
# 15
#
# [協尋] 2021/1/5 行車紀錄器 重慶南路接近衡陽
#
#
# tenth
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 tenth 的文章
#
#
#  1/05
#
#
#
#
# 5
#
# [協尋] 1/6 19：08 中市敦化中平路口 行車記錄器
#
#
# chester0312
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 chester0312 的文章
#
#
#  1/08
#
#
#
#
# 7
#
# [協尋] 找到肇事者了!感謝大家!01/07/20:00彰化秀水馬鳴路
#
#
# alittlekoa
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 alittlekoa 的文章
#
#
#  1/09
#
#
#
#
# 3
#
# Fw: [問題] 協尋一月七號晚上新莊19號越堤道行車
#
#
# lilianstarbo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 lilianstarbo 的文章
#
#
#  1/09
#
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
