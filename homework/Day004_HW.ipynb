# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests 
r = requests.get("https://api.github.com/events")
r.text
# Out:
# '[{"id":"14490377776","type":"PublicEvent","actor":{"id":41773722,"login":"aaeon-kunyi","display_login":"aaeon-kunyi","gravatar_id":"","url":"https://api.github.com/users/aaeon-kunyi","avatar_url":"https://avatars.githubusercontent.com/u/41773722?"},"repo":{"id":274393898,"name":"aaeon-kunyi/bse-kernel","url":"https://api.github.com/repos/aaeon-kunyi/bse-kernel"},"payload":{},"public":true,"created_at":"2020-12-11T02:09:38Z"},{"id":"14490377756","type":"PushEvent","actor":{"id":5436568,"login":"hangc0276","display_login":"hangc0276","gravatar_id":"","url":"https://api.github.com/users/hangc0276","avatar_url":"https://avatars.githubusercontent.com/u/5436568?"},"repo":{"id":249681621,"name":"hangc0276/pulsar","url":"https://api.github.com/repos/hangc0276/pulsar"},"payload":{"push_id":6181584130,"size":1,"distinct_size":1,"ref":"refs/heads/authParams_secret_feature","head":"d8cfeee11e16bbe9a1cd516d1cbd83d892c747dc","before":"a0972e47a9396da743b6a0852106176ca37ce75b","commits":[{"sha":"d8cfeee11e16bbe9a1cd516d1cbd83d892c747dc","author":{"email":"hangc0276@163.com","name":"hangc0276"},"message":"format code","distinct":true,"url":"https://api.github.com/repos/hangc0276/pulsar/commits/d8cfeee11e16bbe9a1cd516d1cbd83d892c747dc"}]},"public":true,"created_at":"2020-12-11T02:09:38Z"},{"id":"14490377742","type":"PushEvent","actor":{"id":943683,"login":"bootingman","display_login":"bootingman","gravatar_id":"","url":"https://api.github.com/users/bootingman","avatar_url":"https://avatars.githubusercontent.com/u/943683?"},"repo":{"id":320439652,"name":"ezgoLinux/conf2014","url":"https://api.github.com/repos/ezgoLinux/conf2014"},"payload":{"push_id":6181584127,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"0876e556bed04752881352d378914ca246d9676e","before":"fcb9165528bfe29becd28e52f38956562d662fdb","commits":[{"sha":"0876e556bed04752881352d378914ca246d9676e","author":{"email":"wen@bootingman.org","name":"Qixiang"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/ezgoLinux/conf2014/commits/0876e556bed04752881352d378914ca246d9676e"}]},"public":true,"created_at":"2020-12-11T02:09:38Z","org":{"id":66687921,"login":"ezgoLinux","gravatar_id":"","url":"https://api.github.com/orgs/ezgoLinux","avatar_url":"https://avatars.githubusercontent.com/u/66687921?"}},{"id":"14490377748","type":"IssueCommentEvent","actor":{"id":37936606,"login":"github-learning-lab[bot]","display_login":"github-learning-lab","gravatar_id":"","url":"https://api.github.com/users/github-learning-lab[bot]","avatar_url":"https://avatars.githubusercontent.com/u/37936606?"},"repo":{"id":320440476,"name":"rstuvel/github-slideshow","url":"https://api.github.com/repos/rstuvel/github-slideshow"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/rstuvel/github-slideshow/issues/1","repository_url":"https://api.github.com/repos/rstuvel/github-slideshow","labels_url":"https://api.github.com/repos/rstuvel/github-slideshow/issues/1/labels{/name}","comments_url":"https://api.github.com/repos/rstuvel/github-slideshow/issues/1/comments","events_url":"https://api.github.com/repos/rstuvel/github-slideshow/issues/1/events","html_url":"https://github.com/rstuvel/github-slideshow/issues/1","id":761790358,"node_id":"MDU6SXNzdWU3NjE3OTAzNTg=","number":1,"title":"Getting Started with GitHub","user":{"login":"github-learning-lab[bot]","id":37936606,"node_id":"MDM6Qm90Mzc5MzY2MDY=","avatar_url":"https://avatars0.githubusercontent.com/in/10572?v=4","gravatar_id":"","url":"https://api.github.com/users/github-learning-lab%5Bbot%5D","html_url":"https://github.com/apps/github-learning-lab","followers_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/followers","following_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/github-learning-lab%5Bbot%5D/starred{/owner} ...

# %%
import json, requests 
r = requests.get("https://api.github.com/events")
json.loads(r.text)
# Out:
# [{'id': '14490379602',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 222777721,
#    'name': 'iotufersa/middleware',
#    'url': 'https://api.github.com/repos/iotufersa/middleware'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/iotufersa/middleware/issues/5',
#     'repository_url': 'https://api.github.com/repos/iotufersa/middleware',
#     'labels_url': 'https://api.github.com/repos/iotufersa/middleware/issues/5/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/iotufersa/middleware/issues/5/comments',
#     'events_url': 'https://api.github.com/repos/iotufersa/middleware/issues/5/events',
#     'html_url': 'https://github.com/iotufersa/middleware/pull/5',
#     'id': 583443181,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzkwMTk4MjU3',
#     'number': 5,
#     'title': 'Bump minimist from 1.2.0 to 1.2.5 in /DeviceManager',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1917019678,
#       'node_id': 'MDU6TGFiZWwxOTE3MDE5Njc4',
#       'url': 'https://api.github.com/repos/iotufersa/middleware/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 11,
#     'created_at': '2020-03-18T03:45:30Z',
#     'updated_at': '2020-12-11T02:09:54Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/iotufersa/middleware/pulls/5',
#      'html_url': 'https://github.com/iotufersa/middleware/pull/5',
#      'diff_url': 'https://github.com/iotufersa/middleware/pull/5.diff',
#      'patch_url': 'https://github.com/iotufersa/middleware/pull/5.patch'},
#     'body': 'Bumps [minimist](https://github.com/substack/minimist) from 1.2.0 to 1.2.5.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/substack/minimist/commit/aeb3e27dae0412de5c0494e9563a5f10c82cc7a9"><code>aeb3e27</code></a> 1.2.5</li>\n<li><a href="https://github.com/substack/minimist/commit/278677b171d956b46613a158c6c486c3ef979b20"><code>278677b</code></a> 1.2.4</li>\n<li><a href="https://github.com/substack/minimist/commit/4cf1354839cb972e38496d35e12f806eea92c11f"><code>4cf1354</code></a> security notice</li>\n<li><a href="https://github.com/substack/minimist/commit/1043d212c3caaf871966e710f52cfdf02f9eea4b"><code>1043d21</code></a> additional test for constructor prototype pollution</li>\n<li><a href="https://github.com/substack/minimist/commit/6457d7440a47f329c12c4a5abfbce211c4235b93"><code>6457d74</code></a> 1.2.3</li>\n<li><a href="https://github.com/substack/minimist/commit/38a4d1caead72ef99e824bb420a2528eec03d9ab"><code>38a4d1c</code></a> even more aggressive checks for protocol pollution</li>\n<li><a href="https://github.com/substack/minimist/commit/13c01a5327736903704984b7f65616b8476850cc"><code>13c01a5</code></a> more failing proto pollution tests</li>\n<li><a href="https://github.com/substack/minimist/commit/f34df077a6b2bee1344188849a95e66777109e89"><code>f34df07</code></a> 1.2.2</li>\n<li><a href="https://github.com/substack/minimist/commit/67d3722413448d00a62963d2d30c34656a92d7e2"><code>67d3722</code></a> cleanup</li>\n<li><a href="https://github.com/substack/minimist/commit/63e7ed05aa4b1889ec2f3b196426db4500cbda94"><code>63e7ed0</code></a> don\'t assign onto <strong>proto</strong></li>\n<li>Additional commits viewable in <a href="https://github.com/substack/minimist/compare/1.2.0...1.2.5">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=minimist&package-manager=npm_and_yarn&previous-version=1.2.0&new-version=1.2.5)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will s ...
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/iotufersa/middleware/issues/comments/742918404',
#     'html_url': 'https://github.com/iotufersa/middleware/pull/5#issuecomment-742918404',
#     'issue_url': 'https://api.github.com/repos/iotufersa/middleware/issues/5',
#     'id': 742918404,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDc0MjkxODQwNA==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-12-11T02:09:54Z',
#     'updated_at': '2020-12-11T02:09:54Z',
#     'author_association': 'NONE',
#     'body': "Dependabot tried to update this pull request, but something went wrong. We're looking into it, but in the meantime you can retry the update by commenting `@dependabot rebase`.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-12-11T02:09:54Z'},
#  {'id': '14490379611',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 165931109,
#    'name': 'Keysox/photography',
#    'url': 'https://api.github.com/repos/Keysox/photography'},
#   'payload': {'action': 'opened',
#    'number': 467,
#    'pull_request': {'url': 'https://api.github.com/repos/Keysox/photography/pulls/467',
#     'id': 536409133,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTM2NDA5MTMz',
#     'html_url': 'https://github.com/Keysox/photography/pull/467',
#     'diff_url': 'https://github.com/Keysox/photography/pull/467.diff',
#     'patch_url': 'https://github.com/Keysox/photography/pull/467.patch',
#     'issue_url': 'https://api.github.com/repos/Keysox/photography/issues/467',
#     'number': 467,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump ini from 1.3.5 to 1.3.7',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [ini](https://github.com/isaacs/ini) from 1.3.5 to 1.3.7.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/npm/ini/commit/c74c8af35f32b801a7e82a8309eab792a95932f6"><code>c74c8af</code></a> 1.3.7</li>\n<li><a href="https://github.com/npm/ini/commit/024b8b55ac1c980c6225607b007714c54eb501ba"><code>024b8b5</code></a> update deps, add linting</li>\n<li><a href="https://github.com/npm/ini/commit/032fbaf5f0b98fce70c8cc380e0d05177a9c9073"><code>032fbaf</code></a> Use Object.create(null) to avoid default object property hazards</li>\n<li><a href="https://github.com/npm/ini/commit/2da90391ef70db41d10f013e3a87f9a8c5d01a72"><code>2da9039</code></a> 1.3.6</li>\n<li><a href="https://github.com/npm/ini/commit/cfea636f534b5ca7550d2c28b7d1a95d936d56c6"><code>cfea636</code></a> better git push script, before publish instead of after</li>\n<li><a href="https://github.com/npm/ini/commit/56d2805e07ccd94e2ba0984ac9240ff02d44b6f1"><code>56d2805</code></a> do not allow invalid hazardous string as section name</li>\n<li>See full diff in <a href="https://github.com/isaacs/ini/compare/v1.3.5...v1.3.7">compare view</a></li>\n</ul>\n</details>\n<details>\n<summary>Maintainer changes</summary>\n<p>This version was pushed to npm by <a href="https://www.npmjs.com/~isaacs">isaacs</a>, a new releaser for ini since your current version.</p>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=ini&package-manager=npm_and_yarn&previous-version=1.3.5&new-version=1.3.7)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will set the current milestone as the default for future PRs for this repo and language\n\nYou can disable automated security fix PRs for this repo from the [Security Alerts page](https://github.com/Keysox/photography/network/alerts).\n\n</details>',
#     'created_at': '2020-12-11T02:09:54Z',
#     'updated_at': '2020-12-11T02:09:54Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Keysox/photography/pulls/467/commits',
#     'review_comments_url': 'https://api.github.com/repos/Keysox/photography/pulls/467/comments',
#     'review_comment_url': 'https://api.github.com/repos/Keysox/photography/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Keysox/photography/issues/467/comments',
#     'statuses_url': 'https://api.github.com/repos/Keysox/photography/statuses/fa1f8d722bf7880f175b806bac179ebacf2af599',
#     'head': {'label': 'Keysox:dependabot/npm_and_yarn/ini-1.3.7',
#      'ref': 'dependabot/npm_and_yarn/ini-1.3.7',
#      'sha': 'fa1f8d722bf7880f175b806bac179ebacf2af599',
#      'user': {'login': 'Keysox',
#       'id': 6796642,
#       'node_id': 'MDQ6VXNlcjY3OTY2NDI=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/6796642?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Keysox',
#       'html_url': 'https://github.com/Keysox',
#       'followers_url': 'https://api.github.com/users/Keysox/followers',
#       'following_url': 'https://api.github.com/users/Keysox/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Keysox/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Keysox/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Keysox/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Keysox/orgs',
#       'repos_url': 'https://api.github.com/users/Keysox/repos',
#       'events_url': 'https://api.github.com/users/Keysox/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Keysox/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 165931109,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjU5MzExMDk=',
#       'name': 'photography',
#       'full_name': 'Keysox/photography',
#       'private': False,
#       'owner': {'login': 'Keysox',
#        'id': 6796642,
#        'node_id': 'MDQ6VXNlcjY3OTY2NDI=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/6796642?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Keysox',
#        'html_url': 'https://github.com/Keysox',
#        'followers_url': 'https://api.github.com/users/Keysox/followers',
#        'following_url': 'https://api.github.com/users/Keysox/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Keysox/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Keysox/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Keysox/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Keysox/orgs',
#        'repos_url': 'https://api.github.com/users/Keysox/repos',
#        'events_url': 'https://api.github.com/users/Keysox/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Keysox/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Keysox/photography',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Keysox/photography',
#       'forks_url': 'https://api.github.com/repos/Keysox/photography/forks',
#       'keys_url': 'https://api.github.com/repos/Keysox/photography/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Keysox/photography/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Keysox/photography/teams',
#       'hooks_url': 'https://api.github.com/repos/Keysox/photography/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Keysox/photography/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Keysox/photography/events',
#       'assignees_url': 'https://api.github.com/repos/Keysox/photography/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Keysox/photography/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Keysox/photography/tags',
#       'blobs_url': 'https://api.github.com/repos/Keysox/photography/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Keysox/photography/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Keysox/photography/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Keysox/photography/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Keysox/photography/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Keysox/photography/languages',
#       'stargazers_url': 'https://api.github.com/repos/Keysox/photography/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Keysox/photography/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Keysox/photography/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Keysox/photography/subscription',
#       'commits_url': 'https://api.github.com/repos/Keysox/photography/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Keysox/photography/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Keysox/photography/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Keysox/photography/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Keysox/photography/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Keysox/photography/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Keysox/photography/merges',
#       'archive_url': 'https://api.github.com/repos/Keysox/photography/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Keysox/photography/downloads',
#       'issues_url': 'https://api.github.com/repos/Keysox/photography/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Keysox/photography/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Keysox/photography/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Keysox/photography/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Keysox/photography/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Keysox/photography/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Keysox/photography/deployments',
#       'created_at': '2019-01-15T22:08:08Z',
#       'updated_at': '2020-12-10T23:57:43Z',
#       'pushed_at': '2020-12-11T02:09:53Z',
#       'git_url': 'git://github.com/Keysox/photography.git',
#       'ssh_url': 'git@github.com:Keysox/photography.git',
#       'clone_url': 'https://github.com/Keysox/photography.git',
#       'svn_url': 'https://github.com/Keysox/photography',
#       'homepage': 'https://alexkessock.com/photography/',
#       'size': 53752,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'Keysox:master',
#      'ref': 'master',
#      'sha': '6962b8cf19f8272c9e5b925b906a037d7d46cd69',
#      'user': {'login': 'Keysox',
#       'id': 6796642,
#       'node_id': 'MDQ6VXNlcjY3OTY2NDI=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/6796642?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Keysox',
#       'html_url': 'https://github.com/Keysox',
#       'followers_url': 'https://api.github.com/users/Keysox/followers',
#       'following_url': 'https://api.github.com/users/Keysox/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Keysox/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Keysox/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Keysox/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Keysox/orgs',
#       'repos_url': 'https://api.github.com/users/Keysox/repos',
#       'events_url': 'https://api.github.com/users/Keysox/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Keysox/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 165931109,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjU5MzExMDk=',
#       'name': 'photography',
#       'full_name': 'Keysox/photography',
#       'private': False,
#       'owner': {'login': 'Keysox',
#        'id': 6796642,
#        'node_id': 'MDQ6VXNlcjY3OTY2NDI=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/6796642?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Keysox',
#        'html_url': 'https://github.com/Keysox',
#        'followers_url': 'https://api.github.com/users/Keysox/followers',
#        'following_url': 'https://api.github.com/users/Keysox/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Keysox/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Keysox/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Keysox/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Keysox/orgs',
#        'repos_url': 'https://api.github.com/users/Keysox/repos',
#        'events_url': 'https://api.github.com/users/Keysox/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Keysox/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Keysox/photography',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Keysox/photography',
#       'forks_url': 'https://api.github.com/repos/Keysox/photography/forks',
#       'keys_url': 'https://api.github.com/repos/Keysox/photography/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Keysox/photography/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Keysox/photography/teams',
#       'hooks_url': 'https://api.github.com/repos/Keysox/photography/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Keysox/photography/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Keysox/photography/events',
#       'assignees_url': 'https://api.github.com/repos/Keysox/photography/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Keysox/photography/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Keysox/photography/tags',
#       'blobs_url': 'https://api.github.com/repos/Keysox/photography/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Keysox/photography/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Keysox/photography/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Keysox/photography/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Keysox/photography/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Keysox/photography/languages',
#       'stargazers_url': 'https://api.github.com/repos/Keysox/photography/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Keysox/photography/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Keysox/photography/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Keysox/photography/subscription',
#       'commits_url': 'https://api.github.com/repos/Keysox/photography/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Keysox/photography/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Keysox/photography/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Keysox/photography/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Keysox/photography/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Keysox/photography/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Keysox/photography/merges',
#       'archive_url': 'https://api.github.com/repos/Keysox/photography/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Keysox/photography/downloads',
#       'issues_url': 'https://api.github.com/repos/Keysox/photography/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Keysox/photography/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Keysox/photography/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Keysox/photography/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Keysox/photography/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Keysox/photography/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Keysox/photography/deployments',
#       'created_at': '2019-01-15T22:08:08Z',
#       'updated_at': '2020-12-10T23:57:43Z',
#       'pushed_at': '2020-12-11T02:09:53Z',
#       'git_url': 'git://github.com/Keysox/photography.git',
#       'ssh_url': 'git@github.com:Keysox/photography.git',
#       'clone_url': 'https://github.com/Keysox/photography.git',
#       'svn_url': 'https://github.com/Keysox/photography',
#       'homepage': 'https://alexkessock.com/photography/',
#       'size': 53752,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Keysox/photography/pulls/467'},
#      'html': {'href': 'https://github.com/Keysox/photography/pull/467'},
#      'issue': {'href': 'https://api.github.com/repos/Keysox/photography/issues/467'},
#      'comments': {'href': 'https://api.github.com/repos/Keysox/photography/issues/467/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Keysox/photography/pulls/467/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Keysox/photography/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Keysox/photography/pulls/467/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Keysox/photography/statuses/fa1f8d722bf7880f175b806bac179ebacf2af599'}},
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-12-11T02:09:54Z'},
#  {'id': '14490379601',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 273707399,
#    'name': 'Obsidion-dev/asyncpixel',
#    'url': 'https://api.github.com/repos/Obsidion-dev/asyncpixel'},
#   'payload': {'ref': 'dependabot/pip/pytype-2020.12.2',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-12-11T02:09:54Z',
#   'org': {'id': 65445105,
#    'login': 'Obsidion-dev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Obsidion-dev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65445105?'}},
#  {'id': '14490379608',
#   'type': 'PushEvent',
#   'actor': {'id': 67295939,
#    'login': 'amyrks1992',
#    'display_login': 'amyrks1992',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amyrks1992',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67295939?'},
#   'repo': {'id': 320441157,
#    'name': 'amyrks1992/Instagram-Clone',
#    'url': 'https://api.github.com/repos/amyrks1992/Instagram-Clone'},
#   'payload': {'push_id': 6181585054,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7e20b7062c10b2039b271222023dff6a6b1a0fd8',
#    'before': 'bddbc839b2ed9d92d60fcd5aee4de7e4c588f0d6',
#    'commits': [{'sha': '7e20b7062c10b2039b271222023dff6a6b1a0fd8',
#      'author': {'email': '67295939+amyrks1992@users.noreply.github.com',
#       'name': 'Amyr Kamel e Silva'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/amyrks1992/Instagram-Clone/commits/7e20b7062c10b2039b271222023dff6a6b1a0fd8'}]},
#   'public': True,
#   'created_at': '2020-12-11T02:09:54Z'},
#  {'id': '14490379597',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 311763023,
#    'name': 'Maexal/maexal.dev',
#    'url': 'https://api.github.com/repos/Maexal/maexal.dev'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/development/snyk-1.436.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-12-11T02:09:54Z',
#   'org': {'id': 66116139,
#    'login': 'Maexal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Maexal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66116139?'}},
#  {'id': '14490379596',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 222777721,
#    'name': 'iotufersa/middleware',
#    'url': 'https://api.github.com/repos/iotufersa/middleware'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/iotufersa/middleware/issues/10',
#     'repository_url': 'https://api.github.com/repos/iotufersa/middleware',
#     'labels_url': 'https://api.github.com/repos/iotufersa/middleware/issues/10/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/iotufersa/middleware/issues/10/comments',
#     'events_url': 'https://api.github.com/repos/iotufersa/middleware/issues/10/events',
#     'html_url': 'https://github.com/iotufersa/middleware/pull/10',
#     'id': 622733897,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDIxNTQxOTQ0',
#     'number': 10,
#     'title': 'Bump minimist from 1.2.0 to 1.2.5 in /src/ActionCommunicator',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1917019678,
#       'node_id': 'MDU6TGFiZWwxOTE3MDE5Njc4',
#       'url': 'https://api.github.com/repos/iotufersa/middleware/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2020-05-21T19:36:34Z',
#     'updated_at': '2020-12-11T02:09:54Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/iotufersa/middleware/pulls/10',
#      'html_url': 'https://github.com/iotufersa/middleware/pull/10',
#      'diff_url': 'https://github.com/iotufersa/middleware/pull/10.diff',
#      'patch_url': 'https://github.com/iotufersa/middleware/pull/10.patch'},
#     'body': 'Bumps [minimist](https://github.com/substack/minimist) from 1.2.0 to 1.2.5.\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/substack/minimist/commit/aeb3e27dae0412de5c0494e9563a5f10c82cc7a9"><code>aeb3e27</code></a> 1.2.5</li>\n<li><a href="https://github.com/substack/minimist/commit/278677b171d956b46613a158c6c486c3ef979b20"><code>278677b</code></a> 1.2.4</li>\n<li><a href="https://github.com/substack/minimist/commit/4cf1354839cb972e38496d35e12f806eea92c11f"><code>4cf1354</code></a> security notice</li>\n<li><a href="https://github.com/substack/minimist/commit/1043d212c3caaf871966e710f52cfdf02f9eea4b"><code>1043d21</code></a> additional test for constructor prototype pollution</li>\n<li><a href="https://github.com/substack/minimist/commit/6457d7440a47f329c12c4a5abfbce211c4235b93"><code>6457d74</code></a> 1.2.3</li>\n<li><a href="https://github.com/substack/minimist/commit/38a4d1caead72ef99e824bb420a2528eec03d9ab"><code>38a4d1c</code></a> even more aggressive checks for protocol pollution</li>\n<li><a href="https://github.com/substack/minimist/commit/13c01a5327736903704984b7f65616b8476850cc"><code>13c01a5</code></a> more failing proto pollution tests</li>\n<li><a href="https://github.com/substack/minimist/commit/f34df077a6b2bee1344188849a95e66777109e89"><code>f34df07</code></a> 1.2.2</li>\n<li><a href="https://github.com/substack/minimist/commit/67d3722413448d00a62963d2d30c34656a92d7e2"><code>67d3722</code></a> cleanup</li>\n<li><a href="https://github.com/substack/minimist/commit/63e7ed05aa4b1889ec2f3b196426db4500cbda94"><code>63e7ed0</code></a> don\'t assign onto <strong>proto</strong></li>\n<li>Additional commits viewable in <a href="https://github.com/substack/minimist/compare/1.2.0...1.2.5">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=minimist&package-manager=npm_and_yarn&previous-version=1.2.0&new-version=1.2.5)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot use these labels` will set the current labels as the default for future PRs for this repo and language\n- `@dependabot use these reviewers` will set the current reviewers as the default for future PRs for this repo and language\n- `@dependabot use these assignees` will set the current assignees as the default for future PRs for this repo and language\n- `@dependabot use this milestone` will s ...
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/iotufersa/middleware/issues/comments/742918403',
#     'html_url': 'https://github.com/iotufersa/middleware/pull/10#issuecomment-742918403',
#     'issue_url': 'https://api.github.com/repos/iotufersa/middleware/issues/10',
#     'id': 742918403,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDc0MjkxODQwMw==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2020-12-11T02:09:54Z',
#     'updated_at': '2020-12-11T02:09:54Z',
#     'author_association': 'NONE',
#     'body': "Dependabot tried to update this pull request, but something went wrong. We're looking into it, but in the meantime you can retry the update by commenting `@dependabot rebase`.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-12-11T02:09:54Z'},
#  {'id': '14490379603',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 222777721,
#    'name': 'iotufersa/middleware',
#    'url': 'https://api.github.com/repos/iotufersa/middleware'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/iotufersa/middleware/issues/6',
#     'repository_url': 'https://api.github.com/repos/iotufersa/middleware',
#     'labels_url': 'https://api.github.com/repos/iotufersa/middleware/issues/6/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/iotufersa/middleware/issues/6/comments',
#     'events_url': 'https://api.github.com/repos/iotufersa/middleware/issues/6/events',
#     'html_url': 'https://github.com/iotufersa/middleware/pull/6',
#     'id': 583443191,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzkwMTk4MjY1',
#     'number': 6,
#     'title': 'Bump minimist from 1.2.0 to 1.2.5 in /ActionManager',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1917019678,
#       'node_id': 'MDU6TGFiZWwxOTE3MDE5Njc4',
#       'url': 'https://api.github.com/repos/iotufersa/middleware/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 12,
#     'created_at': '2020-03-18T03:45:31Z',
#     'updated_at': '2020-12-11T02:09:54Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/iotufersa/middleware/pulls/6',
#      'html_url': 'https://github.com/iotufersa/middleware/pull/6',
#      'diff_url': 'https://github.com/iotufersa/middleware/pull/6.diff',
#      'patch_url': 'https://github.com/iotufersa/middleware/pull/6.patch'},
# ...
#       'starred_url': 'https://api.github.com/users/DFSOrange/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DFSOrange/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DFSOrange/orgs',
#       'repos_url': 'https://api.github.com/users/DFSOrange/repos',
#       'events_url': 'https://api.github.com/users/DFSOrange/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DFSOrange/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 303620563,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMDM2MjA1NjM=',
#       'name': 'servicecomb-service-center',
#       'full_name': 'DFSOrange/servicecomb-service-center',
#       'private': False,
#       'owner': {'login': 'DFSOrange',
#        'id': 26628394,
#        'node_id': 'MDQ6VXNlcjI2NjI4Mzk0',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/26628394?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/DFSOrange',
#        'html_url': 'https://github.com/DFSOrange',
#        'followers_url': 'https://api.github.com/users/DFSOrange/followers',
#        'following_url': 'https://api.github.com/users/DFSOrange/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/DFSOrange/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/DFSOrange/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/DFSOrange/subscriptions',
#        'organizations_url': 'https://api.github.com/users/DFSOrange/orgs',
#        'repos_url': 'https://api.github.com/users/DFSOrange/repos',
#        'events_url': 'https://api.github.com/users/DFSOrange/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/DFSOrange/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/DFSOrange/servicecomb-service-center',
#       'description': 'A standalone service center to allow services to register their instance information and to discover providers of a given service',
#       'fork': True,
#       'url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center',
#       'forks_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/forks',
#       'keys_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/teams',
#       'hooks_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/hooks',
#       'issue_events_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/events',
#       'assignees_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/tags',
#       'blobs_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/languages',
#       'stargazers_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/stargazers',
#       'contributors_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/contributors',
#       'subscribers_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/subscribers',
#       'subscription_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/subscription',
#       'commits_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/merges',
#       'archive_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/downloads',
#       'issues_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/DFSOrange/servicecomb-service-center/deployments',
#       'created_at': '2020-10-13T07:19:28Z',
#       'updated_at': '2020-10-13T07:19:30Z',
#       'pushed_at': '2020-12-10T06:55:15Z',
#       'git_url': 'git://github.com/DFSOrange/servicecomb-service-center.git',
#       'ssh_url': 'git@github.com:DFSOrange/servicecomb-service-center.git',
#       'clone_url': 'https://github.com/DFSOrange/servicecomb-service-center.git',
#       'svn_url': 'https://github.com/DFSOrange/servicecomb-service-center',
#       'homepage': None,
#       'size': 49262,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'apache:master',
#      'ref': 'master',
#      'sha': 'c42253bda08f73d2eddf5d4e62c94d4bc343364b',
#      'user': {'login': 'apache',
#       'id': 47359,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/47359?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/apache',
#       'html_url': 'https://github.com/apache',
#       'followers_url': 'https://api.github.com/users/apache/followers',
#       'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#       'organizations_url': 'https://api.github.com/users/apache/orgs',
#       'repos_url': 'https://api.github.com/users/apache/repos',
#       'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/apache/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 91677514,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk5MTY3NzUxNA==',
#       'name': 'servicecomb-service-center',
#       'full_name': 'apache/servicecomb-service-center',
#       'private': False,
#       'owner': {'login': 'apache',
#        'id': 47359,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ3MzU5',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/47359?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/apache',
#        'html_url': 'https://github.com/apache',
#        'followers_url': 'https://api.github.com/users/apache/followers',
#        'following_url': 'https://api.github.com/users/apache/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/apache/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/apache/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/apache/subscriptions',
#        'organizations_url': 'https://api.github.com/users/apache/orgs',
#        'repos_url': 'https://api.github.com/users/apache/repos',
#        'events_url': 'https://api.github.com/users/apache/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/apache/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/apache/servicecomb-service-center',
#       'description': 'A standalone service center to allow services to register their instance information and to discover providers of a given service',
#       'fork': False,
#       'url': 'https://api.github.com/repos/apache/servicecomb-service-center',
#       'forks_url': 'https://api.github.com/repos/apache/servicecomb-service-center/forks',
#       'keys_url': 'https://api.github.com/repos/apache/servicecomb-service-center/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/apache/servicecomb-service-center/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/apache/servicecomb-service-center/teams',
#       'hooks_url': 'https://api.github.com/repos/apache/servicecomb-service-center/hooks',
#       'issue_events_url': 'https://api.github.com/repos/apache/servicecomb-service-center/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/apache/servicecomb-service-center/events',
#       'assignees_url': 'https://api.github.com/repos/apache/servicecomb-service-center/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/apache/servicecomb-service-center/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/apache/servicecomb-service-center/tags',
#       'blobs_url': 'https://api.github.com/repos/apache/servicecomb-service-center/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/apache/servicecomb-service-center/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/apache/servicecomb-service-center/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/apache/servicecomb-service-center/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/apache/servicecomb-service-center/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/apache/servicecomb-service-center/languages',
#       'stargazers_url': 'https://api.github.com/repos/apache/servicecomb-service-center/stargazers',
#       'contributors_url': 'https://api.github.com/repos/apache/servicecomb-service-center/contributors',
#       'subscribers_url': 'https://api.github.com/repos/apache/servicecomb-service-center/subscribers',
#       'subscription_url': 'https://api.github.com/repos/apache/servicecomb-service-center/subscription',
#       'commits_url': 'https://api.github.com/repos/apache/servicecomb-service-center/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/apache/servicecomb-service-center/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/apache/servicecomb-service-center/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/apache/servicecomb-service-center/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/apache/servicecomb-service-center/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/apache/servicecomb-service-center/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/apache/servicecomb-service-center/merges',
#       'archive_url': 'https://api.github.com/repos/apache/servicecomb-service-center/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/apache/servicecomb-service-center/downloads',
#       'issues_url': 'https://api.github.com/repos/apache/servicecomb-service-center/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/apache/servicecomb-service-center/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/apache/servicecomb-service-center/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/apache/servicecomb-service-center/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/apache/servicecomb-service-center/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/apache/servicecomb-service-center/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/apache/servicecomb-service-center/deployments',
#       'created_at': '2017-05-18T09:53:58Z',
#       'updated_at': '2020-12-10T13:58:49Z',
#       'pushed_at': '2020-12-11T01:53:26Z',
#       'git_url': 'git://github.com/apache/servicecomb-service-center.git',
#       'ssh_url': 'git@github.com:apache/servicecomb-service-center.git',
#       'clone_url': 'https://github.com/apache/servicecomb-service-center.git',
#       'svn_url': 'https://github.com/apache/servicecomb-service-center',
#       'homepage': None,
#       'size': 19393,
#       'stargazers_count': 1156,
#       'watchers_count': 1156,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 286,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 58,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 286,
#       'open_issues': 58,
#       'watchers': 1156,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/apache/servicecomb-service-center/pulls/779'},
#      'html': {'href': 'https://github.com/apache/servicecomb-service-center/pull/779'},
#      'issue': {'href': 'https://api.github.com/repos/apache/servicecomb-service-center/issues/779'},
#      'comments': {'href': 'https://api.github.com/repos/apache/servicecomb-service-center/issues/779/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/apache/servicecomb-service-center/pulls/779/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/apache/servicecomb-service-center/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/apache/servicecomb-service-center/pulls/779/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/apache/servicecomb-service-center/statuses/46364ad79113aab9559d99560230c33650e8ce79'}},
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2020-12-08T11:21:16Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests

r = requests.get("https://cat-fact.herokuapp.com/facts")
r.text
# Out:
# '[{"status":{"verified":true,"sentCount":1,"feedback":""},"type":"cat","deleted":false,"_id":"5887e1d85c873e0011036889","user":"5a9ac18c7478810ea6c06381","text":"Cats make about 100 different sounds. Dogs make only about 10.","__v":0,"source":"user","updatedAt":"2020-09-03T16:39:39.578Z","createdAt":"2018-01-15T21:20:00.003Z","used":true},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"588e746706ac2b00110e59ff","user":"588e6e8806ac2b00110e59c3","text":"Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.","__v":0,"source":"user","updatedAt":"2020-08-26T20:20:02.359Z","createdAt":"2018-01-14T21:20:02.750Z","used":true},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"58923f2fc3878c0011784c79","user":"5887e9f65c873e001103688d","text":"I don\'t know anything about cats.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","createdAt":"2018-02-25T21:20:03.060Z","used":false},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"5894af975cdc7400113ef7f9","user":"5a9ac18c7478810ea6c06381","text":"The technical term for a cat’s hairball is a bezoar.","__v":0,"source":"user","updatedAt":"2020-11-25T21:20:03.895Z","createdAt":"2018-02-27T21:20:02.854Z","used":true},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"58e007cc0aac31001185ecf5","user":"58e007480aac31001185ecef","text":"Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","createdAt":"2018-03-01T21:20:02.713Z","used":false}]'

# %%
import requests
r = requests.get("http://odata.wra.gov.tw/v4/RealtimeWaterLevel")
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 0,\n"value": []}'

# %%
import requests, json 
r = requests.get("http://odata.wra.gov.tw/v4/RealtimeWaterLevel")
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 0,
#  'value': []}

# %%
import csv
with open("./33c92a67434f4de0f0e66b8ed5deee5d_export.csv") as csvFile:
    csvReader = csv.reader(csvFile)
    for line in csvReader:
        print(line)
# Out:
# ['RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLevel', 'RealtimeWaterLev ...
# ['\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n   ...
# ['\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n      \n    ', '\n      \n      \n   ...

# %%
import xmltodict 
with open("./1bcf7f7604b3c587b0b0810cc402e7a5_export.xml") as fd:
    doc = dict(xmltodict.parse(fd.read()))

    datas = doc["table"]["row"][0]["Col1"]["@name"]
    print(datas)
# Out:
# RecordTime

# %%
import requests 
r = requests.get("https://tw.yahoo.com/?p=us")
lines = r.text
#print(lines)
with open("yahooPage.html","w") as fb:
    fbw = fb.write(lines)
