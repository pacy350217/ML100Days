# %% [markdown]
# # 反爬：瀏覽器標頭與基本資訊
#
#
# * 了解「檢查 HTTP 標頭檔」的反爬蟲機制
# * 「檢查 HTTP 標頭檔」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）
# * 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %% [markdown]
# ### 尋找一個網站是有作 Header 檢查的（Hint: 有加跟沒有加回傳結果不一樣）

# %%
import requests 
r = requests.get("https://www.zhihu.com/signin?next=%2F")
resp = r.text 
print(resp)
# Out:
# <html>
# <head><title>403 Forbidden</title></head>
# <body bgcolor="white">
# <center><h1>403 Forbidden</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>

# %% [markdown]
# ### 用上述網站說明該如何判斷 Header 中必須加上哪些資料才會正確

# %%
import requests 
headers = {'authority': 'www.zhihu.com',
'method':'GET',
'path': '/api/v3/oauth/captcha?lang=en',
'scheme': 'https',
'accept': '*/*',
'accept-encoding': 'gzip, deflate, br',
'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
'cookie': '_zap=0a6ace9a-ebbc-42b8-8ec3-8f2b9f021757; d_c0="AEBZgw5aZRKPTv42tqF-Glg12cBRdCDIk1M=|1608819248"; _xsrf=472eccb2-523d-478c-8f98-93dcf9768b7b; capsion_ticket="2|1:0|10:1610254918|14:capsion_ticket|44:YzA0MjNhODcxNmY5NDhmMTkwNDk4NjA5ZjFjMDYyNTA=|880570347d398e464942dd4ebbcd29c999d2258da91b3ca5ade8027705b5a89f"; Hm_lvt_98beee57fd2ef70ccdd5ca52b9740c49=1608819251,1610254918; Hm_lpvt_98beee57fd2ef70ccdd5ca52b9740c49=1610254918; SESSIONID=2GYPfJy7Jdy4I8kabVKj6E9QvJa0gMNS4An6N2j0PvX; JOID=VlwTB0gpm2HqFARsbyms9NICXg5_G946vXVOF1pk_xrcWjsHDGwRnrUTBmxq0Y68zkhcFmEWV80BGwp5a2vUS9w=; osd=VFocC0srnW7mFwZqYCWv9tQNUg19HdE2vndIGFZn_RzTVjgFCmMdnbcVCWBp04izwkteEG4aVM8HFAZ6aW3bR98=; KLBRSID=5430ad6ccb1a51f38ac194049bce5dfe|1610254926|1610254915',
'referer': 'https://www.zhihu.com/signin?next=%2F',
'sec-ch-ua': '"Google Chrome";v="87", " Not;A Brand";v="99", "Chromium";v="87"',
'sec-ch-ua-mobile': '?0',
'sec-fetch-dest': 'empty',
'sec-fetch-mode': 'cors',
'sec-fetch-site': 'same-origin',
'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
'x-ab-param': 'zr_slotpaidexp=1;tp_contents=2;top_test_4_liguangyi=1;pf_noti_entry_num=0;pf_adjust=0;li_panswer_topic=0;li_video_section=0;li_sp_mqbk=0;li_paid_answer_exp=0;qap_question_author=0;zr_expslotpaid=1;tp_topic_style=0;tp_dingyue_video=0;li_vip_verti_search=0;tp_zrec=0;li_edu_page=old;qap_question_visitor= 0;se_ffzx_jushen1=0',
'x-ab-pb': 'ClRnAOQKaAAAAXUMUgs3DJYLtAo/AM8LJgy1C0wLAQEHDPQLGwDCAAgApABCALcA5gBgCw8M3AubC1YMiQy0AA8LAQtsABgB1ws0DOwKRwDFAOEL4AsSKgAAAgAAAQEAAAALAAMAAAAAAAECAAUBAAAAAAIBAAAAAAAAAAABAAABAA==',
'x-requested-with': 'fetch',
'x-zse-83': '3_2.0',
'x-zse-86': '1.0_aXN0nUUBNwFY6MtBMH20ghr8cXSx6MtBsLYB649qrMtf'
}
r = requests.get("https://www.zhihu.com/signin?next=%2F",headers=headers)
resp = r.text 
print(resp)
# Out:
# <!doctype html>
# ...
